# %% [markdown]
# # 📊 Exploratory Data Analysis — Social Media Sentiment Insights
#
# **Objective:**
# Understand the dataset structure, detect missing values, explore distributions and early patterns to guide future modeling or insights presentation.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Visual settings
pd.set_option("display.max_colwidth", 120)
plt.style.use("default")

print("✅ Libraries loaded correctly.")
# Out:
# ✅ Libraries loaded correctly.

# %% [markdown]
# ## 📥 1. Load Dataset & Initial Overview
#
# We'll load the dataset and quickly explore its structure to understand the number of rows, columns, and get a glimpse of the data.

# %%
# Load dataset
df = pd.read_csv("../data/sentimentdataset.csv")
print("Shape:", df.shape)
# Out:
# Shape: (732, 15)

# %%
df.head(30)
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 0              0           0
# 1              1           1
# 2              2           2
# 3              3           3
# 4              4           4
# 5              5           5
# 6              6           6
# 7              7           7
# 8              8           8
# 9              9           9
# 10            10          10
# 11            11          11
# 12            12          12
# 13            13          13
# 14            14          14
# 15            15          15
# 16            16          16
# 17            17          17
# 18            18          18
# 19            19          19
# 20            20          20
# 21            21          21
# 22            22          22
# 23            23          23
# 24            24          24
# 25            25          25
# 26            27          28
# 27            28          29
# 28            29          30
# 29            30          31
#
#                                                     Text    Sentiment  \
# 0    Enjoying a beautiful day at the park!                 Positive
# 1    Traffic was terrible this morning.                    Negative
# 2     Just finished an amazing workout! 💪                  Positive
# 3    Excited about the upcoming weekend getaway!           Positive
# 4    Trying out a new recipe for dinner tonight.           Neutral
# 5    Feeling grateful for the little things in life.       Positive
# 6    Rainy days call for cozy blankets and hot cocoa.      Positive
# 7    The new movie release is a must-watch!                Positive
# 8    Political discussions heating up on the timeline.     Negative
# 9    Missing summer vibes and beach days.                  Neutral
# 10   Just published a new blog post. Check it out!         Positive
# 11   Feeling a bit under the weather today.                Negative
# 12   Exploring the city's hidden gems.                     Positive
# 13    New year, new fitness goals! 💪                       Positive
# 14   Technology is changing the way we live.               Neutral
# 15   Reflecting on the past and looking ahead.             Positive
# 16     Just adopted a cute furry friend! 🐾                 Positive
# 17   Late-night gaming session with friends.               Positive
# 18   Attending a virtual conference on AI.                 Neutral
# 19   Winter blues got me feeling low.                      Negative
# 20   Sipping coffee and enjoying a good book.              Positive
# 21   Exploring the world of virtual reality.               Positive
# 22   Productive day ticking off my to-do list.             Positive
# 23   Just finished a challenging workout routine.          Positive
# 24     Celebrating a milestone at work! 🎉                  Positive
# 25   Sunday brunch with friends.                           Positive
# 26   Learning a new language for personal growth.          Positive
# 27   Quiet evening with a good book.                       Positive
# 28   Reflecting on the importance of mental health.        Positive
# 29    New painting in progress! 🎨                          Positive
#
#               Timestamp                  User     Platform  \
# 0   2023-01-15 12:30:00         User123          Twitter
# 1   2023-01-15 08:45:00         CommuterX        Twitter
# 2   2023-01-15 15:45:00         FitnessFan      Instagram
# 3   2023-01-15 18:20:00         AdventureX       Facebook
# 4   2023-01-15 19:55:00         ChefCook        Instagram
# 5   2023-01-16 09:10:00         GratitudeNow     Twitter
# 6   2023-01-16 14:45:00         RainyDays        Facebook
# 7   2023-01-16 19:30:00         MovieBuff       Instagram
# 8   2023-01-17 08:00:00         DebateTalk       Twitter
# 9   2023-01-17 12:20:00         BeachLover       Facebook
# 10  2023-01-17 15:15:00         BloggerX        Instagram
# 11  2023-01-18 10:30:00         WellnessCheck    Twitter
# 12  2023-01-18 14:50:00         UrbanExplorer    Facebook
# 13  2023-01-18 18:00:00         FitJourney      Instagram
# 14  2023-01-19 09:45:00        TechEnthusiast    Twitter
# 15  2023-01-19 13:20:00         Reflections      Facebook
# 16  2023-01-19 17:10:00         PetAdopter      Instagram
# 17  2023-01-20 00:05:00         GamerX           Twitter
# 18  2023-01-20 11:30:00        TechConference    Facebook
# 19  2023-01-20 15:15:00         WinterBlues     Instagram
# 20  2023-01-21 08:40:00         Bookworm         Twitter
# 21  2023-01-21 13:20:00         VRExplorer       Facebook
# 22  2023-01-21 16:45:00       ProductivityPro   Instagram
# 23  2023-01-22 09:15:00        FitnessWarrior    Twitter
# 24  2023-01-22 14:30:00       CareerMilestone    Facebook
# 25  2023-01-22 12:00:00         BrunchBuddy     Instagram
# 26  2023-01-23 16:20:00       LanguageLearner    Facebook
# 27  2023-01-23 19:45:00         BookLover       Instagram
# 28  2023-01-24 11:30:00   MentalHealthMatters    Twitter
# 29  2023-01-24 15:00:00        ArtistInAction    Facebook
#
#                                       Hashtags  Retweets  Likes       Country  \
# 0    #Nature #Park                                  15.0   30.0     USA
# 1    #Traffic #Morning                               5.0   10.0     Canada
# 2    #Fitness #Workout                              20.0   40.0   USA
# 3    #Travel #Adventure                              8.0   15.0     UK
# 4    #Cooking #Food                                 12.0   25.0    Australia
# 5      #Gratitude #PositiveVibes                    25.0   50.0     India
# 6    #RainyDays #Cozy                               10.0   20.0     Canada
# 7     #MovieNight #MustWatch                        15.0   30.0       USA
# 8     #Politics #Debate                             30.0   60.0     USA
# 9     #Summer #BeachDays                            18.0   35.0    Australia
# 10    #Blogging #NewPost                            22.0   45.0           USA
# 11    #SickDay #Health                               7.0   15.0     Canada
# 12    #CityExplore #HiddenGems                      12.0   25.0     UK
# 13    #NewYear #FitnessGoals                        28.0   55.0   USA
# 14    #Tech #Innovation                             15.0   30.0     India
# 15    #Reflection #Future                           20.0   40.0     USA
# 16    #PetAdoption #FurryFriend                     15.0   30.0    Canada
# 17    #Gaming #LateNight                            18.0   35.0     UK
# 18    #AI #TechConference                           25.0   50.0           USA
# 19    #WinterBlues #Mood                             8.0   15.0    USA
# 20    #Reading #CoffeeTime                          22.0   45.0     India
# 21    #VR #VirtualReality                           15.0   30.0           USA
# 22      #Productivity #WorkFromHome                 30.0   60.0          USA
# 23    #Fitness #ChallengeAccepted                   20.0   40.0     UK
# 24    #Career #Milestone                            12.0   25.0      Canada
# 25     #Brunch #Friends                             15.0   30.0           UK
# 26    #LanguageLearning #PersonalGrowth             25.0   50.0    India
# 27    #Reading #QuietTime                           15.0   30.0    Australia
# 28    #MentalHealth #SelfCare                       22.0   45.0     USA
# 29       #Art #PaintingInProgress                   12.0   25.0       Canada
#
#     Year  Month  Day  Hour
# 0   2023      1   15    12
# 1   2023      1   15     8
# 2   2023      1   15    15
# 3   2023      1   15    18
# 4   2023      1   15    19
# 5   2023      1   16     9
# 6   2023      1   16    14
# 7   2023      1   16    19
# 8   2023      1   17     8
# 9   2023      1   17    12
# 10  2023      1   17    15
# 11  2023      1   18    10
# 12  2023      1   18    14
# 13  2023      1   18    18
# 14  2023      1   19     9
# 15  2023      1   19    13
# 16  2023      1   19    17
# 17  2023      1   20     0
# 18  2023      1   20    11
# 19  2023      1   20    15
# 20  2023      1   21     8
# 21  2023      1   21    13
# 22  2023      1   21    16
# 23  2023      1   22     9
# 24  2023      1   22    14
# 25  2023      1   22    12
# 26  2023      1   23    16
# 27  2023      1   23    19
# 28  2023      1   24    11
# 29  2023      1   24    15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %% [markdown]
# First look:
# 	•	The dataset has 732 rows and 15 columns.
# 	•	There are no missing values, which makes the dataset clean to start with.
#
# About the Unnamed columns:
# 	•	These columns look like index leftovers from the original export.
# 	•	They don’t add any value, so it’s better to drop them to keep the dataset clean.
#
# Data Types:
# 	•	Most columns have appropriate data types for analysis.
# 	•	However, Timestamp is stored as object, so it should be converted to datetime to enable proper time-based analysis.

# %% [markdown]
# Data file has no empty cells (0 non-null values)

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# max     12.000000   31.000000   23.000000

# %% [markdown]
# Note: Most entries fall between 2019 and 2023, indicating that the dataset mainly focuses on recent posts. There is a single entry from 2010, which stands out as a potential temporal outlier worth reviewing.

# %%
df.nunique()
# Out:
# Unnamed: 0.1    732
# Unnamed: 0      732
# Text            707
# Sentiment       279
# Timestamp       683
# User            685
# Platform          4
# Hashtags        697
# Retweets         26
# Likes            38
# Country         115
# Year             14
# Month            12
# Day              31
# Hour             22
# dtype: int64

# %%
df.sort_values(by="Likes", ascending=False).head(10)
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 481           482         486
# 530           531         535
# 382           383         387
# 560           561         565
# 470           471         475
# 550           551         555
# 368           369         373
# 540           541         545
# 355           356         360
# 570           571         575
#
#                                                                                                                         Text  \
# 481                                     Surrounded by the colors of joy, a canvas painted with laughter and endless smiles.
# 530  Captivated by the spellbinding plot twists, the audience applauds, experiencing a rollercoaster of emotions at the m...
# 382                                                  A sense of wonder at the vastness of the cosmos on a stargazing night.
# 560         In the serene beauty of a sunset, nature unfolds a canvas of colors, evoking a sense of tranquility and wonder.
# 470                                        Dancing on sunshine, each step a celebration of the joy found in simple moments.
# 550  After a series of defeats, the soccer team faces disappointment, struggling to find the silver lining in a challengi...
# 368                                                        Elation over discovering a rare book in a quaint bookstore.
# 540  Celebrating a historic victory in the World Cup, the nation erupts in joy, united by the triumph of their football t...
# 355                                                      Anticipation for an upcoming adventure in an exotic destination.
# 570  Underneath the city lights, the dancer expresses emotions through graceful movements, creating a mesmerizing perform...
#
#             Sentiment            Timestamp  \
# 481              Joy   2019-07-02 17:00:00
# 530       Excitement   2018-10-12 20:00:00
# 382       Wonder       2018-07-08 23:00:00
# 560      Tranquility   2021-07-10 19:00:00
# 470              Joy   2021-08-20 15:45:00
# 550   Disappointment   2019-11-02 18:45:00
# 368    Elation         2018-09-22 16:30:00
# 540              Joy   2018-07-15 21:30:00
# 355    Anticipation    2022-07-25 10:00:00
# 570      Mesmerizing   2018-06-15 22:00:00
#
#                                       User     Platform  \
# 481                      ColorfulLaughter    Instagram
# 530       MovieEnthusiastPremiereAttendee      Twitter
# 382                       CosmosExplorer     Instagram
# 560          NatureEnthusiastSunsetWonder    Instagram
# 470                        SunshineDancer    Instagram
# 550                  SoccerFanTeamDefeats      Twitter
# 368                       Bookworm           Instagram
# 540        FootballFanWorldCupCelebration    Instagram
# 355                       Wanderlust          Twitter
# 570   DanceEnthusiastCityNightPerformance      Twitter
#
#                                        Hashtags  Retweets  Likes  \
# 481                        #Joy #EndlessSmiles       40.0   80.0
# 530          #Excitement #MoviePremiereThrills       40.0   80.0
# 382    #Wonder #StargazingAdventure                  40.0   80.0
# 560                 #Tranquility #SunsetBeauty       40.0   80.0
# 470                        #Joy #SimpleMoments       40.0   80.0
# 550             #Disappointment #SoccerDefeats       40.0   80.0
# 368   #Elation #RareBookDiscovery                    40.0   80.0
# 540                      #Joy #WorldCupTriumph       40.0   80.0
# 355   #Anticipation #AdventureAwaits                 40.0   80.0
# 570        #Mesmerizing #NightDancePerformance       40.0   80.0
#
#                  Country  Year  Month  Day  Hour
# 481              Canada   2019      7    2    17
# 530                 USA   2018     10   12    20
# 382     South Africa      2018      7    8    23
# 560              Canada   2021      7   10    19
# 470                 USA   2021      8   20    15
# 550              Brazil   2019     11    2    18
# 368   USA                 2018      9   22    16
# 540              Brazil   2018      7   15    21
# 355   India               2022      7   25    10
# 570                 USA   2018      6   15    22

# %%
df.sort_values(by="Retweets", ascending=False).head(10)
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 570           571         575
# 470           471         475
# 368           369         373
# 540           541         545
# 560           561         565
# 355           356         360
# 402           403         407
# 530           531         535
# 382           383         387
# 432           433         437
#
#                                                                                                                         Text  \
# 570  Underneath the city lights, the dancer expresses emotions through graceful movements, creating a mesmerizing perform...
# 470                                        Dancing on sunshine, each step a celebration of the joy found in simple moments.
# 368                                                        Elation over discovering a rare book in a quaint bookstore.
# 540  Celebrating a historic victory in the World Cup, the nation erupts in joy, united by the triumph of their football t...
# 560         In the serene beauty of a sunset, nature unfolds a canvas of colors, evoking a sense of tranquility and wonder.
# 355                                                      Anticipation for an upcoming adventure in an exotic destination.
# 402                                                     Awe-inspired by the vastness of the cosmos on a stargazing night.
# 530  Captivated by the spellbinding plot twists, the audience applauds, experiencing a rollercoaster of emotions at the m...
# 382                                                  A sense of wonder at the vastness of the cosmos on a stargazing night.
# 432                                                     Heartache deepens, a solitary journey through the abyss of despair.
#
#            Sentiment            Timestamp  \
# 570     Mesmerizing   2018-06-15 22:00:00
# 470             Joy   2021-08-20 15:45:00
# 368   Elation         2018-09-22 16:30:00
# 540             Joy   2018-07-15 21:30:00
# 560     Tranquility   2021-07-10 19:00:00
# 355   Anticipation    2022-07-25 10:00:00
# 402    Wonder         2018-07-08 23:00:00
# 530      Excitement   2018-10-12 20:00:00
# 382      Wonder       2018-07-08 23:00:00
# 432       Despair     2022-08-18 22:00:00
#
#                                       User     Platform  \
# 570   DanceEnthusiastCityNightPerformance      Twitter
# 470                        SunshineDancer    Instagram
# 368                       Bookworm           Instagram
# 540        FootballFanWorldCupCelebration    Instagram
# 560          NatureEnthusiastSunsetWonder    Instagram
# 355                       Wanderlust          Twitter
# 402                       CosmosExplorer     Instagram
# 530       MovieEnthusiastPremiereAttendee      Twitter
# 382                       CosmosExplorer     Instagram
# 432                       SolitaryDescent    Instagram
#
#                                        Hashtags  Retweets  Likes  \
# 570        #Mesmerizing #NightDancePerformance       40.0   80.0
# 470                        #Joy #SimpleMoments       40.0   80.0
# 368   #Elation #RareBookDiscovery                    40.0   80.0
# 540                      #Joy #WorldCupTriumph       40.0   80.0
# 560                 #Tranquility #SunsetBeauty       40.0   80.0
# 355   #Anticipation #AdventureAwaits                 40.0   80.0
# 402    #Wonder #StargazingAdventure                  40.0   80.0
# 530          #Excitement #MoviePremiereThrills       40.0   80.0
# 382    #Wonder #StargazingAdventure                  40.0   80.0
# 432     #Despair #AbyssOfHeartache                   40.0   80.0
#
#                  Country  Year  Month  Day  Hour
# 570                 USA   2018      6   15    22
# 470                 USA   2021      8   20    15
# 368   USA                 2018      9   22    16
# 540              Brazil   2018      7   15    21
# 560              Canada   2021      7   10    19
# 355   India               2022      7   25    10
# 402     South Africa      2018      7    8    23
# 530                 USA   2018     10   12    20
# 382     South Africa      2018      7    8    23
# 432        South Africa   2022      8   18    22

# %%
# pd.set_option('display.float_format', lambda x: '%.2f' % x)
df_corr = df.corr(numeric_only=True).round(2)
df_corr.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# df.corr(numeric_only=True)
# Out:
# <style type="text/css">
# #T_ce80f_row0_col0, #T_ce80f_row0_col1, #T_ce80f_row1_col0, #T_ce80f_row1_col1, #T_ce80f_row2_col2, #T_ce80f_row2_col3, #T_ce80f_row3_col2, #T_ce80f_row3_col3, #T_ce80f_row4_col4, #T_ce80f_row5_col5, #T_ce80f_row6_col6, #T_ce80f_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ce80f_row0_col2, #T_ce80f_row1_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_ce80f_row0_col3, #T_ce80f_row1_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ce80f_row0_col4, #T_ce80f_row1_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ce80f_row0_col5, #T_ce80f_row1_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_ce80f_row0_col6, #T_ce80f_row1_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ce80f_row0_col7, #T_ce80f_row1_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ce80f_row2_col0, #T_ce80f_row2_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_ce80f_row2_col4, #T_ce80f_row3_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ce80f_row2_col5, #T_ce80f_row3_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ce80f_row2_col6, #T_ce80f_row3_col6, #T_ce80f_row6_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ce80f_row2_col7, #T_ce80f_row3_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ce80f_row3_col0, #T_ce80f_row3_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ce80f_row4_col0, #T_ce80f_row4_col1, #T_ce80f_row7_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ce80f_row4_col2, #T_ce80f_row4_col3, #T_ce80f_row4_col5, #T_ce80f_row4_col7, #T_ce80f_row5_col4, #T_ce80f_row5_col6, #T_ce80f_row6_col0, #T_ce80f_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ce80f_row4_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_ce80f_row5_col0, #T_ce80f_row5_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_ce80f_row5_col2, #T_ce80f_row5_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ce80f_row5_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ce80f_row6_col2, #T_ce80f_row6_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ce80f_row6_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ce80f_row6_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ce80f_row7_col0, #T_ce80f_row7_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ce80f_row7_col2, #T_ce80f_row7_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ce80f_row7_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_ce80f_row7_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce80f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce80f_level0_col0" class="col_heading level0 col0" >Unnamed: 0.1</th>
#       <th id="T_ce80f_level0_col1" class="col_heading level0 col1" >Unnamed: 0</th>
#       <th id="T_ce80f_level0_col2" class="col_heading level0 col2" >Retweets</th>
#       <th id="T_ce80f_level0_col3" class="col_heading level0 col3" >Likes</th>
#       <th id="T_ce80f_level0_col4" class="col_heading level0 col4" >Year</th>
#       <th id="T_ce80f_level0_col5" class="col_heading level0 col5" >Month</th>
#       <th id="T_ce80f_level0_col6" class="col_heading level0 col6" >Day</th>
#       <th id="T_ce80f_level0_col7" class="col_heading level0 col7" >Hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce80f_level0_row0" class="row_heading level0 row0" >Unnamed: 0.1</th>
#       <td id="T_ce80f_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ce80f_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_ce80f_row0_col2" class="data row0 col2" >0.39</td>
#       <td id="T_ce80f_row0_col3" class="data row0 col3" >0.38</td>
#       <td id="T_ce80f_row0_col4" class="data row0 col4" >0.10</td>
#       <td id="T_ce80f_row0_col5" class="data row0 col5" >0.44</td>
#       <td id="T_ce80f_row0_col6" class="data row0 col6" >-0.08</td>
#       <td id="T_ce80f_row0_col7" class="data row0 col7" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_ce80f_level0_row1" class="row_heading level0 row1" >Unnamed: 0</th>
#       <td id="T_ce80f_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_ce80f_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ce80f_row1_col2" class="data row1 col2" >0.39</td>
#       <td id="T_ce80f_row1_col3" class="data row1 col3" >0.38</td>
#       <td id="T_ce80f_row1_col4" class="data row1 col4" >0.10</td>
#       <td id="T_ce80f_row1_col5" class="data row1 col5" >0.44</td>
#       <td id="T_ce80f_row1_col6" class="data row1 col6" >-0.08</td>
#       <td id="T_ce80f_row1_col7" class="data row1 col7" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_ce80f_level0_row2" class="row_heading level0 row2" >Retweets</th>
#       <td id="T_ce80f_row2_col0" class="data row2 col0" >0.39</td>
#       <td id="T_ce80f_row2_col1" class="data row2 col1" >0.39</td>
#       <td id="T_ce80f_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_ce80f_row2_col3" class="data row2 col3" >1.00</td>
#       <td id="T_ce80f_row2_col4" class="data row2 col4" >-0.04</td>
#       <td id="T_ce80f_row2_col5" class="data row2 col5" >0.07</td>
#       <td id="T_ce80f_row2_col6" class="data row2 col6" >0.01</td>
#       <td id="T_ce80f_row2_col7" class="data row2 col7" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_ce80f_level0_row3" class="row_heading level0 row3" >Likes</th>
#       <td id="T_ce80f_row3_col0" class="data row3 col0" >0.38</td>
#       <td id="T_ce80f_row3_col1" class="data row3 col1" >0.38</td>
#       <td id="T_ce80f_row3_col2" class="data row3 col2" >1.00</td>
#       <td id="T_ce80f_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_ce80f_row3_col4" class="data row3 col4" >-0.04</td>
#       <td id="T_ce80f_row3_col5" class="data row3 col5" >0.07</td>
#       <td id="T_ce80f_row3_col6" class="data row3 col6" >0.01</td>
#       <td id="T_ce80f_row3_col7" class="data row3 col7" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_ce80f_level0_row4" class="row_heading level0 row4" >Year</th>
#       <td id="T_ce80f_row4_col0" class="data row4 col0" >0.10</td>
#       <td id="T_ce80f_row4_col1" class="data row4 col1" >0.10</td>
#       <td id="T_ce80f_row4_col2" class="data row4 col2" >-0.04</td>
#       <td id="T_ce80f_row4_col3" class="data row4 col3" >-0.04</td>
#       <td id="T_ce80f_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_ce80f_row4_col5" class="data row4 col5" >-0.31</td>
#       <td id="T_ce80f_row4_col6" class="data row4 col6" >0.02</td>
#       <td id="T_ce80f_row4_col7" class="data row4 col7" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_ce80f_level0_row5" class="row_heading level0 row5" >Month</th>
#       <td id="T_ce80f_row5_col0" class="data row5 col0" >0.44</td>
#       <td id="T_ce80f_row5_col1" class="data row5 col1" >0.44</td>
#       <td id="T_ce80f_row5_col2" class="data row5 col2" >0.07</td>
#       <td id="T_ce80f_row5_col3" class="data row5 col3" >0.07</td>
#       <td id="T_ce80f_row5_col4" class="data row5 col4" >-0.31</td>
#       <td id="T_ce80f_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_ce80f_row5_col6" class="data row5 col6" >-0.14</td>
#       <td id="T_ce80f_row5_col7" class="data row5 col7" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_ce80f_level0_row6" class="row_heading level0 row6" >Day</th>
#       <td id="T_ce80f_row6_col0" class="data row6 col0" >-0.08</td>
#       <td id="T_ce80f_row6_col1" class="data row6 col1" >-0.08</td>
#       <td id="T_ce80f_row6_col2" class="data row6 col2" >0.01</td>
#       <td id="T_ce80f_row6_col3" class="data row6 col3" >0.01</td>
#       <td id="T_ce80f_row6_col4" class="data row6 col4" >0.02</td>
#       <td id="T_ce80f_row6_col5" class="data row6 col5" >-0.14</td>
#       <td id="T_ce80f_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_ce80f_row6_col7" class="data row6 col7" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_ce80f_level0_row7" class="row_heading level0 row7" >Hour</th>
#       <td id="T_ce80f_row7_col0" class="data row7 col0" >0.32</td>
#       <td id

# %% [markdown]
# Unnamed data should be removed
# Total correlation between likes and retweets

# %%
df_corr = df.corr(numeric_only=True).round(2)
df_corr.style.format("{:.2f}").background_gradient(cmap="magma")
# Out:
# <style type="text/css">
# #T_de775_row0_col0, #T_de775_row0_col1, #T_de775_row1_col0, #T_de775_row1_col1, #T_de775_row2_col2, #T_de775_row2_col3, #T_de775_row3_col2, #T_de775_row3_col3, #T_de775_row4_col4, #T_de775_row5_col5, #T_de775_row6_col6, #T_de775_row7_col7 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_de775_row0_col2, #T_de775_row1_col2 {
#   background-color: #912b81;
#   color: #f1f1f1;
# }
# #T_de775_row0_col3, #T_de775_row1_col3 {
#   background-color: #8e2a81;
#   color: #f1f1f1;
# }
# #T_de775_row0_col4, #T_de775_row1_col4 {
#   background-color: #6a1c81;
#   color: #f1f1f1;
# }
# #T_de775_row0_col5, #T_de775_row1_col5 {
#   background-color: #d3436e;
#   color: #f1f1f1;
# }
# #T_de775_row0_col6, #T_de775_row1_col6 {
#   background-color: #07061c;
#   color: #f1f1f1;
# }
# #T_de775_row0_col7, #T_de775_row1_col7 {
#   background-color: #832681;
#   color: #f1f1f1;
# }
# #T_de775_row2_col0, #T_de775_row2_col1 {
#   background-color: #9b2e7f;
#   color: #f1f1f1;
# }
# #T_de775_row2_col4, #T_de775_row3_col4 {
#   background-color: #3d0f71;
#   color: #f1f1f1;
# }
# #T_de775_row2_col5, #T_de775_row3_col5 {
#   background-color: #601880;
#   color: #f1f1f1;
# }
# #T_de775_row2_col6, #T_de775_row3_col6, #T_de775_row6_col5 {
#   background-color: #1e1149;
#   color: #f1f1f1;
# }
# #T_de775_row2_col7, #T_de775_row3_col7 {
#   background-color: #57157e;
#   color: #f1f1f1;
# }
# #T_de775_row3_col0, #T_de775_row3_col1 {
#   background-color: #982d80;
#   color: #f1f1f1;
# }
# #T_de775_row4_col0, #T_de775_row4_col1, #T_de775_row7_col4 {
#   background-color: #2c115f;
#   color: #f1f1f1;
# }
# #T_de775_row4_col2, #T_de775_row4_col3, #T_de775_row4_col5, #T_de775_row4_col7, #T_de775_row5_col4, #T_de775_row5_col6, #T_de775_row6_col0, #T_de775_row6_col1 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_de775_row4_col6 {
#   background-color: #21114e;
#   color: #f1f1f1;
# }
# #T_de775_row5_col0, #T_de775_row5_col1 {
#   background-color: #ae347b;
#   color: #f1f1f1;
# }
# #T_de775_row5_col2, #T_de775_row5_col3 {
#   background-color: #160f3b;
#   color: #f1f1f1;
# }
# #T_de775_row5_col7 {
#   background-color: #400f74;
#   color: #f1f1f1;
# }
# #T_de775_row6_col2, #T_de775_row6_col3 {
#   background-color: #06051a;
#   color: #f1f1f1;
# }
# #T_de775_row6_col4 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_de775_row6_col7 {
#   background-color: #1a1042;
#   color: #f1f1f1;
# }
# #T_de775_row7_col0, #T_de775_row7_col1 {
#   background-color: #802582;
#   color: #f1f1f1;
# }
# #T_de775_row7_col2, #T_de775_row7_col3 {
#   background-color: #491078;
#   color: #f1f1f1;
# }
# #T_de775_row7_col5 {
#   background-color: #752181;
#   color: #f1f1f1;
# }
# #T_de775_row7_col6 {
#   background-color: #29115a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de775">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de775_level0_col0" class="col_heading level0 col0" >Unnamed: 0.1</th>
#       <th id="T_de775_level0_col1" class="col_heading level0 col1" >Unnamed: 0</th>
#       <th id="T_de775_level0_col2" class="col_heading level0 col2" >Retweets</th>
#       <th id="T_de775_level0_col3" class="col_heading level0 col3" >Likes</th>
#       <th id="T_de775_level0_col4" class="col_heading level0 col4" >Year</th>
#       <th id="T_de775_level0_col5" class="col_heading level0 col5" >Month</th>
#       <th id="T_de775_level0_col6" class="col_heading level0 col6" >Day</th>
#       <th id="T_de775_level0_col7" class="col_heading level0 col7" >Hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de775_level0_row0" class="row_heading level0 row0" >Unnamed: 0.1</th>
#       <td id="T_de775_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_de775_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_de775_row0_col2" class="data row0 col2" >0.39</td>
#       <td id="T_de775_row0_col3" class="data row0 col3" >0.38</td>
#       <td id="T_de775_row0_col4" class="data row0 col4" >0.10</td>
#       <td id="T_de775_row0_col5" class="data row0 col5" >0.44</td>
#       <td id="T_de775_row0_col6" class="data row0 col6" >-0.08</td>
#       <td id="T_de775_row0_col7" class="data row0 col7" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_de775_level0_row1" class="row_heading level0 row1" >Unnamed: 0</th>
#       <td id="T_de775_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_de775_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_de775_row1_col2" class="data row1 col2" >0.39</td>
#       <td id="T_de775_row1_col3" class="data row1 col3" >0.38</td>
#       <td id="T_de775_row1_col4" class="data row1 col4" >0.10</td>
#       <td id="T_de775_row1_col5" class="data row1 col5" >0.44</td>
#       <td id="T_de775_row1_col6" class="data row1 col6" >-0.08</td>
#       <td id="T_de775_row1_col7" class="data row1 col7" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_de775_level0_row2" class="row_heading level0 row2" >Retweets</th>
#       <td id="T_de775_row2_col0" class="data row2 col0" >0.39</td>
#       <td id="T_de775_row2_col1" class="data row2 col1" >0.39</td>
#       <td id="T_de775_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_de775_row2_col3" class="data row2 col3" >1.00</td>
#       <td id="T_de775_row2_col4" class="data row2 col4" >-0.04</td>
#       <td id="T_de775_row2_col5" class="data row2 col5" >0.07</td>
#       <td id="T_de775_row2_col6" class="data row2 col6" >0.01</td>
#       <td id="T_de775_row2_col7" class="data row2 col7" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_de775_level0_row3" class="row_heading level0 row3" >Likes</th>
#       <td id="T_de775_row3_col0" class="data row3 col0" >0.38</td>
#       <td id="T_de775_row3_col1" class="data row3 col1" >0.38</td>
#       <td id="T_de775_row3_col2" class="data row3 col2" >1.00</td>
#       <td id="T_de775_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_de775_row3_col4" class="data row3 col4" >-0.04</td>
#       <td id="T_de775_row3_col5" class="data row3 col5" >0.07</td>
#       <td id="T_de775_row3_col6" class="data row3 col6" >0.01</td>
#       <td id="T_de775_row3_col7" class="data row3 col7" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_de775_level0_row4" class="row_heading level0 row4" >Year</th>
#       <td id="T_de775_row4_col0" class="data row4 col0" >0.10</td>
#       <td id="T_de775_row4_col1" class="data row4 col1" >0.10</td>
#       <td id="T_de775_row4_col2" class="data row4 col2" >-0.04</td>
#       <td id="T_de775_row4_col3" class="data row4 col3" >-0.04</td>
#       <td id="T_de775_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_de775_row4_col5" class="data row4 col5" >-0.31</td>
#       <td id="T_de775_row4_col6" class="data row4 col6" >0.02</td>
#       <td id="T_de775_row4_col7" class="data row4 col7" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_de775_level0_row5" class="row_heading level0 row5" >Month</th>
#       <td id="T_de775_row5_col0" class="data row5 col0" >0.44</td>
#       <td id="T_de775_row5_col1" class="data row5 col1" >0.44</td>
#       <td id="T_de775_row5_col2" class="data row5 col2" >0.07</td>
#       <td id="T_de775_row5_col3" class="data row5 col3" >0.07</td>
#       <td id="T_de775_row5_col4" class="data row5 col4" >-0.31</td>
#       <td id="T_de775_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_de775_row5_col6" class="data row5 col6" >-0.14</td>
#       <td id="T_de775_row5_col7" class="data row5 col7" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_de775_level0_row6" class="row_heading level0 row6" >Day</th>
#       <td id="T_de775_row6_col0" class="data row6 col0" >-0.08</td>
#       <td id="T_de775_row6_col1" class="data row6 col1" >-0.08</td>
#       <td id="T_de775_row6_col2" class="data row6 col2" >0.01</td>
#       <td id="T_de775_row6_col3" class="data row6 col3" >0.01</td>
#       <td id="T_de775_row6_col4" class="data row6 col4" >0.02</td>
#       <td id="T_de775_row6_col5" class="data row6 col5" >-0.14</td>
#       <td id="T_de775_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_de775_row6_col7" class="data row6 col7" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_de775_level0_row7" class="row_heading level0 row7" >Hour</th>
#       <td id="T_de775_row7_col0" class="data row7 col0" >0.32</td>
#       <td id

# %% [markdown]
# When applying a background gradient, especially in data visualization libraries like Pandas or Matplotlib, the cmap argument (colormap) specifies the color scheme to be used. While coolwarm provides a diverging colormap ranging from cool blues to warm reds, many other options exist, each with a distinct aesthetic and purpose.
# Here are some categories of colormaps and examples of other colors you could use:
# 1. Sequential Colormaps: These colormaps are designed to show a progression of values, typically from low to high, using a single hue or a gradual change in lightness/saturation.
# Examples: viridis, plasma, inferno, magma, gray, Blues, Greens, Reds, Purples, Oranges.
# 2. Diverging Colormaps: Similar to coolwarm, these colormaps emphasize a central neutral value and diverge to two distinct colors at the extremes, suitable for showing deviations from a mean or a zero point.
# Examples: seismic, RdBu, PiYG, PRGn, BrBG, bwr.
# 3. Qualitative Colormaps: These colormaps are designed to distinguish between discrete categories or groups, using distinct and easily differentiable colors.
# Examples: tab10, tab20, Paired, Set1, Set2, Dark2.
# 4. Cyclic Colormaps: These colormaps are useful for data that wraps around a central point, like angles or phases, where the start and end colors are the same or very similar.
# Examples: twilight, hsv.
# To choose the best colormap, consider:
# Data Type: Is your data sequential, diverging, or categorical?
# Clarity: Does the colormap effectively convey the information without causing misinterpretations?
# Accessibility: Is the colormap colorblind-friendly? (e.g., viridis is often recommended for this).
# Aesthetics: Does the colormap align with the overall design and purpose of your visualization?

# %%
df['text_len'] = df['Text'].str.len()
df['word_count'] = df['Text'].str.split().str.len()
df['hashtag_count'] = df['Hashtags'].str.count('#')
df['emoji_count'] = df['Text'].str.count(r'[^\w\s,]')  # emojis/símbolos

df[['text_len', 'word_count', 'hashtag_count', 'emoji_count', 'Likes', 'Retweets']].corr()
# Out:
#                text_len  word_count  hashtag_count  emoji_count     Likes  \
# text_len       1.000000    0.941527            NaN     0.351973  0.186922
# word_count     0.941527    1.000000            NaN     0.261845  0.196229
# hashtag_count       NaN         NaN            NaN          NaN       NaN
# emoji_count    0.351973    0.261845            NaN     1.000000  0.174394
# Likes          0.186922    0.196229            NaN     0.174394  1.000000
# Retweets       0.188660    0.197125            NaN     0.181458  0.998482
#
#                Retweets
# text_len       0.188660
# word_count     0.197125
# hashtag_count       NaN
# emoji_count    0.181458
# Likes          0.998482
# Retweets       1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True)

plt.rcParams['figure.figsize'] = (20,7)

plt.show()

# %%
df_groupby = df.groupby('Platform')[['Likes', 'Retweets']].mean().sort_values(by='Likes', ascending=False)
df_groupby.style.format("{:.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8eff7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8eff7_level0_col0" class="col_heading level0 col0" >Likes</th>
#       <th id="T_8eff7_level0_col1" class="col_heading level0 col1" >Retweets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Platform</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eff7_level0_row0" class="row_heading level0 row0" > Twitter </th>
#       <td id="T_8eff7_row0_col0" class="data row0 col0" >45.4</td>
#       <td id="T_8eff7_row0_col1" class="data row0 col1" >22.8</td>
#     </tr>
#     <tr>
#       <th id="T_8eff7_level0_row1" class="row_heading level0 row1" > Instagram </th>
#       <td id="T_8eff7_row1_col0" class="data row1 col0" >45.1</td>
#       <td id="T_8eff7_row1_col1" class="data row1 col1" >22.6</td>
#     </tr>
#     <tr>
#       <th id="T_8eff7_level0_row2" class="row_heading level0 row2" > Facebook </th>
#       <td id="T_8eff7_row2_col0" class="data row2 col0" >41.9</td>
#       <td id="T_8eff7_row2_col1" class="data row2 col1" >21.0</td>
#     </tr>
#     <tr>
#       <th id="T_8eff7_level0_row3" class="row_heading level0 row3" > Twitter  </th>
#       <td id="T_8eff7_row3_col0" class="data row3 col0" >37.3</td>
#       <td id="T_8eff7_row3_col1" class="data row3 col1" >18.7</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Country'].value_counts()
# Out:
# Country
# USA               59
# USA               55
# UK                49
# Canada            44
# Australia         41
#                   ..
# Netherlands        1
# USA                1
# Germany            1
# France             1
# USA                1
# Name: count, Length: 115, dtype: int64

# %% [markdown]
# Strings might have empty values and that messes up de 'country' data

# %%
df['Country'].value_counts(normalize=True) * 100
# Out:
# Country
# USA               8.060109
# USA               7.513661
# UK                6.693989
# Canada            6.010929
# Australia         5.601093
#                     ...
# Netherlands       0.136612
# USA               0.136612
# Germany           0.136612
# France            0.136612
# USA               0.136612
# Name: proportion, Length: 115, dtype: float64

# %%
df.groupby('Country')[['Likes', 'Retweets', 'emoji_count', 'word_count']].mean().sort_values(by='Likes', ascending=False)
# Out:
#                          Likes  Retweets  emoji_count  word_count
# Country
# India                80.000000      40.0          1.0    9.000000
# South Africa         80.000000      40.0          1.5   12.500000
# Belgium              70.000000      35.0          1.0   10.500000
# Japan                70.000000      35.0          1.0   12.000000
# Netherlands          70.000000      35.0          1.0   17.000000
# ...                        ...       ...          ...         ...
# Canada               25.000000      12.0          2.0    6.000000
# Australia            24.200000      12.0          1.2   11.000000
# Canada               21.666667      11.0          1.0   10.666667
# India                21.000000      10.4          1.4   10.200000
# USA                  15.000000       8.0          1.0    7.000000
#
# [115 rows x 4 columns]

# %%
df_groupby = df.groupby('Sentiment')[['Likes', 'Retweets']].mean().sort_values(by='Retweets', ascending=False)
df_groupby.style.format("{:.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac4a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac4a0_level0_col0" class="col_heading level0 col0" >Likes</th>
#       <th id="T_ac4a0_level0_col1" class="col_heading level0 col1" >Retweets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sentiment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac4a0_level0_row0" class="row_heading level0 row0" > Motivation    </th>
#       <td id="T_ac4a0_row0_col0" class="data row0 col0" >80.0</td>
#       <td id="T_ac4a0_row0_col1" class="data row0 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row1" class="row_heading level0 row1" > Mesmerizing </th>
#       <td id="T_ac4a0_row1_col0" class="data row1 col0" >80.0</td>
#       <td id="T_ac4a0_row1_col1" class="data row1 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row2" class="row_heading level0 row2" > Wonder     </th>
#       <td id="T_ac4a0_row2_col0" class="data row2 col0" >80.0</td>
#       <td id="T_ac4a0_row2_col1" class="data row2 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row3" class="row_heading level0 row3" > Wonder       </th>
#       <td id="T_ac4a0_row3_col0" class="data row3 col0" >80.0</td>
#       <td id="T_ac4a0_row3_col1" class="data row3 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row4" class="row_heading level0 row4" > Anticipation  </th>
#       <td id="T_ac4a0_row4_col0" class="data row4 col0" >80.0</td>
#       <td id="T_ac4a0_row4_col1" class="data row4 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row5" class="row_heading level0 row5" > Thrill        </th>
#       <td id="T_ac4a0_row5_col0" class="data row5 col0" >80.0</td>
#       <td id="T_ac4a0_row5_col1" class="data row5 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row6" class="row_heading level0 row6" > Imagination </th>
#       <td id="T_ac4a0_row6_col0" class="data row6 col0" >70.0</td>
#       <td id="T_ac4a0_row6_col1" class="data row6 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row7" class="row_heading level0 row7" > Whispers of the Past </th>
#       <td id="T_ac4a0_row7_col0" class="data row7 col0" >70.0</td>
#       <td id="T_ac4a0_row7_col1" class="data row7 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row8" class="row_heading level0 row8" > Emotion </th>
#       <td id="T_ac4a0_row8_col0" class="data row8 col0" >70.0</td>
#       <td id="T_ac4a0_row8_col1" class="data row8 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row9" class="row_heading level0 row9" > Ecstasy </th>
#       <td id="T_ac4a0_row9_col0" class="data row9 col0" >70.0</td>
#       <td id="T_ac4a0_row9_col1" class="data row9 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row10" class="row_heading level0 row10" > CulinaryOdyssey </th>
#       <td id="T_ac4a0_row10_col0" class="data row10 col0" >70.0</td>
#       <td id="T_ac4a0_row10_col1" class="data row10 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row11" class="row_heading level0 row11" > Harmony    </th>
#       <td id="T_ac4a0_row11_col0" class="data row11 col0" >70.0</td>
#       <td id="T_ac4a0_row11_col1" class="data row11 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row12" class="row_heading level0 row12" > Harmony       </th>
#       <td id="T_ac4a0_row12_col0" class="data row12 col0" >70.0</td>
#       <td id="T_ac4a0_row12_col1" class="data row12 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row13" class="row_heading level0 row13" > Mindfulness   </th>
#       <td id="T_ac4a0_row13_col0" class="data row13 col0" >70.0</td>
#       <td id="T_ac4a0_row13_col1" class="data row13 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row14" class="row_heading level0 row14" > Love </th>
#       <td id="T_ac4a0_row14_col0" class="data row14 col0" >70.0</td>
#       <td id="T_ac4a0_row14_col1" class="data row14 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row15" class="row_heading level0 row15" > Resilience </th>
#       <td id="T_ac4a0_row15_col0" class="data row15 col0" >70.0</td>
#       <td id="T_ac4a0_row15_col1" class="data row15 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row16" class="row_heading level0 row16" > Suspense </th>
#       <td id="T_ac4a0_row16_col0" class="data row16 col0" >70.0</td>
#       <td id="T_ac4a0_row16_col1" class="data row16 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row17" class="row_heading level0 row17" > Resilience   </th>
#       <td id="T_ac4a0_row17_col0" class="data row17 col0" >70.0</td>
#       <td id="T_ac4a0_row17_col1" class="data row17 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row18" class="row_heading level0 row18" > Culinary Adventure </th>
#       <td id="T_ac4a0_row18_col0" class="data row18 col0" >70.0</td>
#       <td id="T_ac4a0_row18_col1" class="data row18 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row19" class="row_heading level0 row19" > Wonderment    </th>
#       <td id="T_ac4a0_row19_col0" class="data row19 col0" >70.0</td>
#       <td id="T_ac4a0_row19_col1" class="data row19 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row20" class="row_heading level0 row20" > InnerJourney  </th>
#       <td id="T_ac4a0_row20_col0" class="data row20 col0" >70.0</td>
#       <td id="T_ac4a0_row20_col1" class="data row20 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row21" class="row_heading level0 row21" > Exhaustion </th>
#       <td id="T_ac4a0_row21_col0" class="data row21 col0" >70.0</td>
#       <td id="T_ac4a0_row21_col1" class="data row21 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row22" class="row_heading level0 row22" > Gratitude   </th>
#       <td id="T_ac4a0_row22_col0" class="data row22 col0" >70.0</td>
#       <td id="T_ac4a0_row22_col1" class="data row22 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row23" class="row_heading level0 row23" > Euphoria </th>
#       <td id="T_ac4a0_row23_col0" class="data row23 col0" >70.0</td>
#       <td id="T_ac4a0_row23_col1" class="data row23 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row24" class="row_heading level0 row24" > Enthusiasm </th>
#       <td id="T_ac4a0_row24_col0" class="data row24 col0" >70.0</td>
#       <td id="T_ac4a0_row24_col1" class="data row24 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row25" class="row_heading level0 row25" > Challenge </th>
#       <td id="T_ac4a0_row25_col0" class="data row25 col0" >70.0</td>
#       <td id="T_ac4a0_row25_col1" class="data row25 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row26" class="row_heading level0 row26" > Energy </th>
#       <td id="T_ac4a0_row26_col0" class="data row26 col0" >70.0</td>
#       <td id="T_ac4a0_row26_col1" class="data row26 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row27" class="row_heading level0 row27" > Despair   </th>
#       <td id="T_ac4a0_row27_col0" class="data row27 col0" >67.5</td>
#       <td id="T_ac4a0_row27_col1" class="data row27 col1" >34.0</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row28" class="row_heading level0 row28" > Isolation </th>
#       <td id="T_ac4a0_row28_col0" class="data row28 col0" >65.0</td>
#       <td id="T_ac4a0_row28_col1" class="data row28 col1" >32.5</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row29" class="row_heading level0 row29" > Happiness </th>
#       <td id="T_ac4a0_row29_col0" class="data row29 col0" >65.0</td>
#       <td id="T_ac4a0_row29_col1" class="data row29 col1" >32.5</td>
#     </tr>
#     <tr>
#       <th id="T_ac4a0_level0_row30" class="row_heading level0 row30" > Tranquility </th>
#       <td id="T_ac4a0_row30_col0" class="data row30 col0" >65.0</td>
#       <td id="T_ac4a0_row30_col1" class="data row30

# %%
# --- CLEANUP ---
# Clean the 'Platform' column to avoid duplicates like 'Twitter ' vs 'twitter'
df["Platform"] = df["Platform"].astype(str).str.strip().str.title()

# %%
print(df.head())
print(df.shape)

df.drop(columns='Unnamed: 0.1', inplace=True)
df.rename(columns={'Unnamed: 0':'Id'}, inplace=True)
df.isnull().sum()
df.dtypes

df["Platform"] = df["Platform"].astype(str).str.strip().str.title()
top10_sentiments = df["Sentiment"].value_counts().head(10).index
df_platform = df[df["Sentiment"].isin(top10_sentiments)].copy()

print("Platforms in dataset:", df_platform["Platform"].unique())
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                    Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!                 Positive
# 1   Traffic was terrible this morning.                    Negative
# 2    Just finished an amazing workout! 💪                  Positive
# 3   Excited about the upcoming weekend getaway!           Positive
# 4   Trying out a new recipe for dinner tonight.           Neutral
#
#              Timestamp            User   Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan     Instagram
# 3  2023-01-15 18:20:00   AdventureX      Facebook
# 4  2023-01-15 19:55:00   ChefCook       Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
# 3   #Travel #Adventure                              8.0   15.0     UK
# 4   #Cooking #Food                                 12.0   25.0    Australia
#
#    Year  Month  Day  Hour  text_len  word_count  hashtag_count  emoji_count
# 0  2023      1   15    12        52           7              2            1
# 1  2023      1   15     8        52           5              2            1
# 2  2023      1   15    15        51           6              2            2
# 3  2023      1   15    18        52           6              2            1
# 4  2023      1   15    19        52           8              2            1
# (732, 19)
# Platforms in dataset: ['Twitter' 'Instagram' 'Facebook']

# %%
# --- Clean Platform ---
print("\nCleaning Platform column...")
df["Platform"] = df["Platform"].astype(str).str.strip()                 # Remove leading/trailing spaces
df["Platform"] = df["Platform"].str.replace(r"\s+", " ", regex=True)    # Replace multiple spaces with single space
df["Platform"] = df["Platform"].str.title()                             # Standardize case
print("Unique platforms after cleaning:", df["Platform"].unique())

# --- Clean Country ---
print("\nCleaning Country column...")
df["Country"] = df["Country"].astype(str).str.strip()                   # Remove leading/trailing spaces
df["Country"] = df["Country"].str.replace(r"\s+", " ", regex=True)      # Replace multiple spaces with single space
df["Country"] = df["Country"].str.title()                               # Standardize case

# Map variations to standardized names
country_mapping = {
    "Usa": "USA",
    "U.S.": "USA",
    "United States": "USA",
    "United States Of America": "USA",
    "Uk": "United Kingdom",
    "U.K.": "United Kingdom",
    "England": "United Kingdom",
    "Korea": "South Korea"
}
df["Country"] = df["Country"].replace(country_mapping)

print("Unique countries after cleaning:", df["Country"].unique()[:20])

# =========================
# 3. Simplify Sentiments into Positive / Neutral / Negative
# =========================
print("\nStep 3: Simplifying sentiments into Positive / Neutral / Negative")

sentiment_categories = {
    "Positive": [
        "Positive", "Happiness", "Joy", "Love", "Amusement", "Enjoyment",
        "Admiration", "Affection", "Awe", "Surprise", "Acceptance",
        "Adoration", "Anticipation", "Calmness", "Excitement", "Kind",
        "Pride", "Elation", "Euphoria", "Contentment", "Serenity",
        "Gratitude", "Hope", "Empowerment", "Compassion", "Tenderness",
        "Enthusiasm", "Fulfillment", "Reverence", "Zest", "Hopeful",
        "Proud", "Grateful", "Empathetic", "Compassionate", "Playful",
        "Inspired", "Confident", "Optimism", "Positivity", "Kindness",
        "Friendship", "Success", "Satisfaction", "Triumph", "Heartwarming"
    ],
    "Neutral": [
        "Neutral", "Confusion", "Indifference", "Curiosity", "Ambivalence",
        "Reflection", "Contemplation", "Acceptance", "Serenity", "Calmness"
    ],
    "Negative": [
        "Negative", "Anger", "Fear", "Sadness", "Disgust", "Disappointed",
        "Bitter", "Shame", "Despair", "Grief", "Loneliness", "Jealousy",
        "Resentment", "Frustration", "Boredom", "Anxiety", "Intimidation",
        "Helplessness", "Envy", "Regret", "Melancholy", "Nostalgia",
        "Yearning", "Fearful", "Apprehensive", "Overwhelmed", "Devastated",
        "Dismissive", "Heartbreak", "Betrayal", "Suffering", "Loss",
        "Isolation", "Exhaustion", "Sorrow", "Darkness", "Desperation",
        "Ruins", "Desolation", "Hate", "Bad", "Sad"
    ]
}

# Create a table of sentiment categories
df_sentiments = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in sentiment_categories.items()]))
print("\nSentiment Categories Table:")
print(df_sentiments)

# Function to simplify sentiment
def simplify_sentiment(s):
    s = str(s).strip()
    if s in sentiment_categories["Positive"]:
        return "Positive"
    elif s in sentiment_categories["Neutral"]:
        return "Neutral"
    else:
        return "Negative"

df["SentimentSimple"] = df["Sentiment"].apply(simplify_sentiment)
print("Unique simplified sentiments:", df["SentimentSimple"].unique())
# Out:
# Cleaning Platform column...
# Unique platforms after cleaning: ['Twitter' 'Instagram' 'Facebook']
#
# Cleaning Country column...
# Unique countries after cleaning: ['USA' 'Canada' 'United Kingdom' 'Australia' 'India' 'France' 'Brazil'
#  'Japan' 'Greece' 'Germany' 'Sweden' 'Italy' 'Netherlands' 'South Africa'
#  'Spain' 'Portugal' 'Switzerland' 'Austria' 'Belgium' 'Denmark']
#
# Step 3: Simplifying sentiments into Positive / Neutral / Negative
#
# Sentiment Categories Table:
#          Positive        Neutral      Negative
# 0        Positive        Neutral      Negative
# 1       Happiness      Confusion         Anger
# 2             Joy   Indifference          Fear
# 3            Love      Curiosity       Sadness
# 4       Amusement    Ambivalence       Disgust
# 5       Enjoyment     Reflection  Disappointed
# 6      Admiration  Contemplation        Bitter
# 7       Affection     Acceptance         Shame
# 8             Awe       Serenity       Despair
# 9        Surprise       Calmness         Grief
# 10     Acceptance            NaN    Loneliness
# 11      Adoration            NaN      Jealousy
# 12   Anticipation            NaN    Resentment
# 13       Calmness            NaN   Frustration
# 14     Excitement            NaN       Boredom
# 15           Kind            NaN       Anxiety
# 16          Pride            NaN  Intimidation
# 17        Elation            NaN  Helplessness
# 18       Euphoria            NaN          Envy
# 19    Contentment            NaN        Regret
# 20       Serenity            NaN    Melancholy
# 21      Gratitude            NaN     Nostalgia
# 22           Hope            NaN      Yearning
# 23    Empowerment            NaN       Fearful
# 24     Compassion            NaN  Apprehensive
# 25     Tenderness            NaN   Overwhelmed
# 26     Enthusiasm            NaN    Devastated
# 27    Fulfillment            NaN    Dismissive
# 28      Reverence            NaN    Heartbreak
# 29           Zest            NaN      Betrayal
# 30        Hopeful            NaN     Suffering
# 31          Proud            NaN          Loss
# 32       Grateful            NaN     Isolation
# 33     Empathetic            NaN    Exhaustion
# 34  Compassionate            NaN        Sorrow
# 35        Playful            NaN      Darkness
# 36       Inspired            NaN   Desperation
# 37      Confident            NaN         Ruins
# 38       Optimism            NaN    Desolation
# 39     Positivity            NaN          Hate
# 40       Kindness            NaN           Bad
# 41     Friendship            NaN           Sad
# 42        Success            NaN           NaN
# 43   Satisfaction            NaN           NaN
# 44        Triumph            NaN           NaN
# 45   Heartwarming            NaN           NaN
# Unique simplified sentiments: ['Positive' 'Negative' 'Neutral']

# %%
# --- Sentiment Color Mapping (mood-based palette) ---
sentiment_colors = {
    # Positive (greens)
    'Contentment': '#66BB6A',   # soft green
    'Excitement':  '#43A047',   # vivid green
    'Gratitude':   '#81C784',   # light green
    'Happy':       '#2E7D32',   # deep green
    'Hopeful':     '#A5D6A7',   # pale green
    'Positive':    '#1B5E20',   # dark forest green
    'Joy':         '#4CAF50',   # balanced green

    # Neutral (greys)
    'Neutral':     '#9E9E9E',   # medium grey
    'Curiosity':   '#BDBDBD',   # light grey

    # Negative (reds)
    'Sad':         '#FFB6C1'    # warm red
}

# --- Normalize and Clean Columns for Consistency ---
# Ensure Sentiment column is clean and matches dictionary keys
df["Sentiment_norm"] = df["Sentiment"].astype(str).str.strip().str.title()

# Clean Platform and Country names for consistency
if "Platform" in df.columns:
    df["Platform"] = df["Platform"].astype(str).str.strip().str.title()
if "Country" in df.columns:
    df["Country"] = df["Country"].astype(str).str.strip().str.title()

# --- Optional: preview unique sentiment values to confirm alignment ---
print("✅ Sentiment categories found:", df["Sentiment_norm"].unique())
print("✅ Sentiment color keys:", list(sentiment_colors.keys()))
print("✅ Setup complete — ready to visualize!")
# Out:
# ✅ Sentiment categories found: ['Positive' 'Negative' 'Neutral' 'Anger' 'Fear' 'Sadness' 'Disgust'
#  'Happiness' 'Joy' 'Love' 'Amusement' 'Enjoyment' 'Admiration' 'Affection'
#  'Awe' 'Disappointed' 'Surprise' 'Acceptance' 'Adoration' 'Anticipation'
#  'Bitter' 'Calmness' 'Confusion' 'Excitement' 'Kind' 'Pride' 'Shame'
#  'Elation' 'Euphoria' 'Contentment' 'Serenity' 'Gratitude' 'Hope'
#  'Empowerment' 'Compassion' 'Tenderness' 'Arousal' 'Enthusiasm'
#  'Fulfillment' 'Reverence' 'Despair' 'Grief' 'Loneliness' 'Jealousy'
#  'Resentment' 'Frustration' 'Boredom' 'Anxiety' 'Intimidation'
#  'Helplessness' 'Envy' 'Regret' 'Curiosity' 'Indifference' 'Numbness'
#  'Melancholy' 'Nostalgia' 'Ambivalence' 'Determination' 'Zest' 'Hopeful'
#  'Proud' 'Grateful' 'Empathetic' 'Compassionate' 'Playful' 'Free-Spirited'
#  'Inspired' 'Confident' 'Bitterness' 'Yearning' 'Fearful' 'Apprehensive'
#  'Overwhelmed' 'Jealous' 'Devastated' 'Frustrated' 'Envious' 'Dismissive'
#  'Thrill' 'Bittersweet' 'Overjoyed' 'Inspiration' 'Motivation'
#  'Contemplation' 'Joyfulreunion' 'Satisfaction' 'Blessed' 'Reflection'
#  'Appreciation' 'Confidence' 'Accomplishment' 'Wonderment' 'Optimism'
#  'Enchantment' 'Intrigue' 'Playfuljoy' 'Mindfulness' 'Dreamchaser'
#  'Elegance' 'Whimsy' 'Pensive' 'Harmony' 'Creativity' 'Radiance' 'Wonder'
#  'Rejuvenation' 'Coziness' 'Adventure' 'Melodic' 'Festivejoy'
#  'Innerjourney' 'Freedom' 'Dazzle' 'Adrenaline' 'Artisticburst'
#  'Culinaryodyssey' 'Resilience' 'Immersion' 'Spark' 'Marvel' 'Heartbreak'
#  'Betrayal' 'Suffering' 'Emotionalstorm' 'Isolation' 'Disappointment'
#  'Lostlove' 'Exhaustion' 'Sorrow' 'Darkness' 'Desperation' 'Ruins'
#  'Desolation' 'Loss' 'Heartache' 'Solitude' 'Positivity' 'Kindness'
#  'Friendship' 'Success' 'Exploration' 'Amazement' 'Romance' 'Captivation'
#  'Tranquility' 'Grandeur' 'Emotion' 'Energy' 'Celebration' 'Charm'
#  'Ecstasy' 'Colorful' 'Hypnotic' 'Connection' 'Iconic' 'Journey'
#  'Engagement' 'Touched' 'Suspense' 'Triumph' 'Heartwarming' 'Obstacle'
#  'Sympathy' 'Pressure' 'Renewed Effort' 'Miscalculation' 'Challenge'
#  'Solace' 'Breakthrough' 'Joy In Baking' 'Envisioning History'
#  'Imagination' 'Vibrancy' 'Mesmerizing' 'Culinary Adventure'
#  'Winter Magic' 'Thrilling Journey' "Nature'S Beauty" 'Celestial Wonder'
#  'Creative Inspiration' 'Runway Creativity' "Ocean'S Freedom"
#  'Whispers Of The Past' 'Relief' 'Embarrassed' 'Mischievous' 'Sad' 'Hate'
#  'Bad' 'Happy']
# ✅ Sentiment color keys: ['Contentment', 'Excitement', 'Gratitude', 'Happy', 'Hopeful', 'Positive', 'Joy', 'Neutral', 'Curiosity', 'Sad']
# ✅ Setup complete — ready to visualize!

# %%
# --- Normalize sentiment labels once (avoids case/space mismatches) ---
df_platform["Sentiment_norm"] = df_platform["Sentiment"].astype(str).str.strip().str.title()

# --- Extract month (1..12) ---
df_platform["Month"] = pd.to_datetime(df_platform["Timestamp"], errors="coerce").dt.month

# --- Plot monthly sentiment trends per platform with consistent colors ---
for platform in df_platform["Platform"].unique():
    sub = df_platform[df_platform["Platform"] == platform]

    monthly = (
        sub.groupby(["Month", "Sentiment_norm"])
           .size()
           .reset_index(name="Count")
    )

    # Pivot to wide; ensure months appear 1..12 in order
    pivot_month = monthly.pivot_table(
        index="Month", columns="Sentiment_norm", values="Count", fill_value=0
    ).reindex(range(1, 13), fill_value=0)

    # Build color list matching the pivot column order
    col_order = list(pivot_month.columns)
    color_list = [sentiment_colors.get(col, '#CCCCCC') for col in col_order]

    # Area plot with our palette
    ax = pivot_month.plot(
        kind="area",
        alpha=0.85,
        figsize=(9, 5),
        color=color_list
    )
    ax.set_title(f"Monthly Sentiment Trends on {platform} (Top 10 Sentiments)")
    ax.set_xlabel("Month")
    ax.set_ylabel("Post Count")

    # Legend consistent with column order
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels, title="Sentiment", fontsize=7, ncol=2, bbox_to_anchor=(1.02, 1), loc="upper left")
    plt.tight_layout()
    plt.show()

# %%
# --- Normalize sentiment labels to match color keys ---
df["Sentiment_norm"] = df["Sentiment"].astype(str).str.strip().str.title()

# Clean Country column
df["Country"] = df["Country"].astype(str).str.strip().str.title()

# Keep only top 10 countries (most posts)
top_countries = df["Country"].value_counts().head(10).index
df_geo = df[df["Country"].isin(top_countries)].copy()

# Keep only top 10 sentiments for readability (use normalized field)
top10_sentiments = df["Sentiment_norm"].value_counts().head(10).index
df_geo = df_geo[df_geo["Sentiment_norm"].isin(top10_sentiments)].copy()

# --- 3) Sentiment distribution by country (Top 10) ---
country_sentiment = (
    df_geo.groupby(["Country", "Sentiment_norm"])
          .size()
          .unstack(fill_value=0)
)

# Order columns to a consistent mood order & build matching colors
ordered_cols = [s for s in sentiment_colors.keys() if s in country_sentiment.columns]
# (If any other sentiments remain, append them at the end)
ordered_cols += [s for s in country_sentiment.columns if s not in ordered_cols]

color_list = [sentiment_colors.get(s, "#CCCCCC") for s in ordered_cols]

# Plot stacked bars with our palette
ax = country_sentiment[ordered_cols].plot(
    kind="bar",
    stacked=True,
    figsize=(10, 6),
    color=color_list
)

ax.set_title("Sentiment Distribution by Country (Top 10)")
ax.set_xlabel("Country")
ax.set_ylabel("Number of Posts")
ax.legend(title="Sentiment", fontsize=7, ncol=2, bbox_to_anchor=(1.02, 1), loc="upper left")
plt.tight_layout()
plt.show()


'''
Top three countries, positive sentiment distribution is the highest across all three 
countries, with words such as positive, joy, and excitement taking the lead
'''
# Out:
# '\nTop three countries, positive sentiment distribution is the highest across all three \ncountries, with words such as positive, joy, and excitement taking the lead\n'

# %%
# --- 4) platform usage by country TOP 10 ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Clean up text columns
df["Country"] = df["Country"].astype(str).str.strip().str.title()
df["Platform"] = df["Platform"].astype(str).str.strip().str.title()

# Focus on top 10 countries (most posts)
top_countries = df["Country"].value_counts().head(10).index
df_country_platform = df[df["Country"].isin(top_countries)].copy()

heat_data = (
    df_country_platform.groupby(["Country", "Platform"])
    .size()
    .unstack(fill_value=0)
)

plt.figure(figsize=(10,6))
sns.heatmap(heat_data, cmap="YlGnBu", annot=True, fmt="d")
plt.title("Heatmap of Platform Usage by Country (Top 10)")
plt.xlabel("Platform")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

''' Instagram is the number one platform used across the top three countries and majority of the other Top 10s
However, India has Twitter as the most used platform'''
# Out:
# ' Instagram is the number one platform used across the top three countries and majority of the other Top 10s\nHowever, India has Twitter as the most used platform'

# %% [markdown]
# ' Instagram is the number one platform used across the top three countries and majority of the other Top 10s\nHowever, India has Twitter as the most used platform'

# %%
# =========================
# Platform Distribution
# =========================

print("\nPlatform Distribution (with simplified sentiments)")

sentiment_palette = {
    "Positive": "#90EE90",   # LightGreen
    "Neutral":  "#D3D3D3",   # LightGray
    "Negative": "#FFB6C1"    # LightPink
}

plt.figure(figsize=(8,6))
sns.countplot(x="Platform", hue="SentimentSimple", data=df,
              order=df["Platform"].value_counts().index,
              palette=sentiment_palette)
plt.title("Platform Distribution by Sentiment (3 categories)")
plt.xticks(rotation=45, ha="right")
plt.show()

# =========================
# Sentiment by Country (Top 10 countries)
# =========================

print("\nSentiment by Country (Top 10 countries, simplified sentiments)")

top_countries = df["Country"].value_counts().nlargest(10).index

plt.figure(figsize=(12,6))
sns.countplot(x="Country", hue="SentimentSimple",
              data=df[df["Country"].isin(top_countries)],
              order=top_countries,
              palette=sentiment_palette)
plt.title("Top 10 Countries by Sentiment (3 categories)")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# Platform Distribution (with simplified sentiments)
# Sentiment by Country (Top 10 countries, simplified sentiments)

# %%
# =========================
# Engagement by Sentiment
# =========================
print("\nEngagement by Sentiment ( Retweets / Likes)")

engagement_summary = df.groupby("SentimentSimple")[["Retweets", "Likes"]].mean().round(2)
print(engagement_summary)

plt.figure(figsize=(8,6))
engagement_summary.plot(kind="bar", figsize=(8,6), color=["skyblue","orange"])
plt.title("Average Engagement (Retweets & Likes) by Sentiment")
plt.ylabel("Average Count")
plt.xticks(rotation=0)
plt.show()
# Out:
# Engagement by Sentiment ( Retweets / Likes)
#                  Retweets  Likes
# SentimentSimple
# Negative            21.18  42.25
# Neutral             19.58  38.97
# Positive            22.18  44.26

# %%
# =========================
# Text Length Grouping
# =========================
print("\nSentiment Distribution by Text Length Group")


df["TextLength"] = df["Text"].astype(str).str.len()


bins = list(range(0, 211, 30))  # [0, 30, 60, ..., 210]
labels = [f"{i}-{i+29}" for i in bins[:-1]]
labels[-1] = "180-210"  


df["LengthGroup"] = pd.cut(df["TextLength"], bins=bins, labels=labels, right=False)


plt.figure(figsize=(10,6))
sns.countplot(x="LengthGroup", hue="SentimentSimple", data=df, palette=sentiment_palette)
plt.title("Sentiment Distribution by Text Length Group")
plt.show()


# =========================
# Engagement by Text Length Group
# =========================
print("\nAverage Engagement by Text Length Group")


engagement_by_length = df.groupby("LengthGroup", observed=True)[["Likes","Retweets"]].mean()


engagement_by_length.plot(kind="bar", figsize=(10,6), color=["#90EE90", "#FFB6C1"])
plt.title("Average Engagement (Likes & Retweets) by Text Length Group")
plt.ylabel("Average Likes / Retweets")
plt.show()
# Out:
# Sentiment Distribution by Text Length Group
# Average Engagement by Text Length Group
