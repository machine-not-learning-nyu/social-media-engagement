# %% [markdown]
# # 📊 Test Exploratory Data Analysis — Social Media Sentiment Insights
#
# **Objective:**
# Understand the dataset structure, detect missing values, explore distributions and early patterns to guide future modeling or insights presentation.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Visual settings
pd.set_option("display.max_colwidth", 120)
plt.style.use("default")

print("✅ Libraries loaded correctly.")
# Out:
# ✅ Libraries loaded correctly.

# %% [markdown]
# ## 📥 1. Load Dataset & Initial Overview
#
# We'll load the dataset and quickly explore its structure to understand the number of rows, columns, and get a glimpse of the data.

# %%
# Load dataset
df = pd.read_csv("../data/sentimentdataset.csv")
print("✅ Dataset loaded. Shape:", df.shape)
# Out:
# ✅ Dataset loaded. Shape: (732, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         732 non-null    int64
#  1   Text       732 non-null    object
#  2   Sentiment  732 non-null    object
#  3   Timestamp  732 non-null    datetime64[ns]
#  4   User       732 non-null    object
#  5   Platform   732 non-null    object
#  6   Hashtags   732 non-null    object
#  7   Retweets   732 non-null    float64
#  8   Likes      732 non-null    float64
#  9   Country    732 non-null    object
#  10  Year       732 non-null    int32
#  11  Month      732 non-null    int32
#  12  Day        732 non-null    int32
#  13  Hour       732 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int32(3), int64(2), object(6)
# memory usage: 71.6+ KB

# %%
df.describe()
# Out:
#                Id                      Timestamp    Retweets       Likes  \
# count  732.000000                            732  732.000000  732.000000
# mean   369.740437  2020-12-08 21:37:38.196721408   21.508197   42.901639
# min      0.000000            2010-05-15 15:30:00    5.000000   10.000000
# 25%    185.750000            2019-03-08 17:27:30   17.750000   34.750000
# 50%    370.500000            2021-09-20 14:30:00   22.000000   43.000000
# 75%    553.250000            2023-02-26 11:48:45   25.000000   50.000000
# max    736.000000            2023-10-22 20:45:00   40.000000   80.000000
# std    212.428936                            NaN    7.061286   14.089848
#
#               Year       Month         Day        Hour
# count   732.000000  732.000000  732.000000  732.000000
# mean   2020.471311    6.122951   15.497268   15.521858
# min    2010.000000    1.000000    1.000000    0.000000
# 25%    2019.000000    3.000000    9.000000   13.000000
# 50%    2021.000000    6.000000   15.000000   16.000000
# 75%    2023.000000    9.000000   22.000000   19.000000
# max    2023.000000   12.000000   31.000000   23.000000
# std       2.802285    3.411763    8.474553    4.113414

# %%
df.isnull().sum()
# Out:
# Id           0
# Text         0
# Sentiment    0
# Timestamp    0
# User         0
# Platform     0
# Hashtags     0
# Retweets     0
# Likes        0
# Country      0
# Year         0
# Month        0
# Day          0
# Hour         0
# dtype: int64

# %%
df.nunique()
# Out:
# Id           732
# Text         706
# Sentiment    191
# Timestamp    683
# User         670
# Platform       3
# Hashtags     692
# Retweets      26
# Likes         38
# Country       33
# Year          14
# Month         12
# Day           31
# Hour          22
# dtype: int64

# %%
df.sort_values(by="Likes", ascending=False).head(10)
# Out:
#       Id  \
# 481  486
# 530  535
# 382  387
# 560  565
# 470  475
# 550  555
# 368  373
# 540  545
# 355  360
# 570  575
#
#                                                                                                                         Text  \
# 481                                      Surrounded by the colors of joy, a canvas painted with laughter and endless smiles.
# 530  Captivated by the spellbinding plot twists, the audience applauds, experiencing a rollercoaster of emotions at the m...
# 382                                                   A sense of wonder at the vastness of the cosmos on a stargazing night.
# 560          In the serene beauty of a sunset, nature unfolds a canvas of colors, evoking a sense of tranquility and wonder.
# 470                                         Dancing on sunshine, each step a celebration of the joy found in simple moments.
# 550  After a series of defeats, the soccer team faces disappointment, struggling to find the silver lining in a challengi...
# 368                                                              Elation over discovering a rare book in a quaint bookstore.
# 540  Celebrating a historic victory in the World Cup, the nation erupts in joy, united by the triumph of their football t...
# 355                                                         Anticipation for an upcoming adventure in an exotic destination.
# 570  Underneath the city lights, the dancer expresses emotions through graceful movements, creating a mesmerizing perform...
#
#           Sentiment           Timestamp                                 User  \
# 481             Joy 2019-07-02 17:00:00                     ColorfulLaughter
# 530      Excitement 2018-10-12 20:00:00      MovieEnthusiastPremiereAttendee
# 382          Wonder 2018-07-08 23:00:00                       CosmosExplorer
# 560     Tranquility 2021-07-10 19:00:00         NatureEnthusiastSunsetWonder
# 470             Joy 2021-08-20 15:45:00                       SunshineDancer
# 550  Disappointment 2019-11-02 18:45:00                 SoccerFanTeamDefeats
# 368         Elation 2018-09-22 16:30:00                             Bookworm
# 540             Joy 2018-07-15 21:30:00       FootballFanWorldCupCelebration
# 355    Anticipation 2022-07-25 10:00:00                           Wanderlust
# 570     Mesmerizing 2018-06-15 22:00:00  DanceEnthusiastCityNightPerformance
#
#       Platform                             Hashtags  Retweets  Likes  \
# 481  Instagram                  #Joy #EndlessSmiles      40.0   80.0
# 530    Twitter    #Excitement #MoviePremiereThrills      40.0   80.0
# 382  Instagram         #Wonder #StargazingAdventure      40.0   80.0
# 560  Instagram           #Tranquility #SunsetBeauty      40.0   80.0
# 470  Instagram                  #Joy #SimpleMoments      40.0   80.0
# 550    Twitter       #Disappointment #SoccerDefeats      40.0   80.0
# 368  Instagram          #Elation #RareBookDiscovery      40.0   80.0
# 540  Instagram                #Joy #WorldCupTriumph      40.0   80.0
# 355    Twitter       #Anticipation #AdventureAwaits      40.0   80.0
# 570    Twitter  #Mesmerizing #NightDancePerformance      40.0   80.0
#
#           Country  Year  Month  Day  Hour
# 481        Canada  2019      7    2    17
# 530           USA  2018     10   12    20
# 382  South Africa  2018      7    8    23
# 560        Canada  2021      7   10    19
# 470           USA  2021      8   20    15
# 550        Brazil  2019     11    2    18
# 368           USA  2018      9   22    16
# 540        Brazil  2018      7   15    21
# 355         India  2022      7   25    10
# 570           USA  2018      6   15    22

# %%
df.sort_values(by="Retweets", ascending=False).head(10)
# Out:
#       Id  \
# 570  575
# 470  475
# 368  373
# 540  545
# 560  565
# 355  360
# 402  407
# 530  535
# 382  387
# 432  437
#
#                                                                                                                         Text  \
# 570  Underneath the city lights, the dancer expresses emotions through graceful movements, creating a mesmerizing perform...
# 470                                         Dancing on sunshine, each step a celebration of the joy found in simple moments.
# 368                                                              Elation over discovering a rare book in a quaint bookstore.
# 540  Celebrating a historic victory in the World Cup, the nation erupts in joy, united by the triumph of their football t...
# 560          In the serene beauty of a sunset, nature unfolds a canvas of colors, evoking a sense of tranquility and wonder.
# 355                                                         Anticipation for an upcoming adventure in an exotic destination.
# 402                                                        Awe-inspired by the vastness of the cosmos on a stargazing night.
# 530  Captivated by the spellbinding plot twists, the audience applauds, experiencing a rollercoaster of emotions at the m...
# 382                                                   A sense of wonder at the vastness of the cosmos on a stargazing night.
# 432                                                      Heartache deepens, a solitary journey through the abyss of despair.
#
#         Sentiment           Timestamp                                 User  \
# 570   Mesmerizing 2018-06-15 22:00:00  DanceEnthusiastCityNightPerformance
# 470           Joy 2021-08-20 15:45:00                       SunshineDancer
# 368       Elation 2018-09-22 16:30:00                             Bookworm
# 540           Joy 2018-07-15 21:30:00       FootballFanWorldCupCelebration
# 560   Tranquility 2021-07-10 19:00:00         NatureEnthusiastSunsetWonder
# 355  Anticipation 2022-07-25 10:00:00                           Wanderlust
# 402        Wonder 2018-07-08 23:00:00                       CosmosExplorer
# 530    Excitement 2018-10-12 20:00:00      MovieEnthusiastPremiereAttendee
# 382        Wonder 2018-07-08 23:00:00                       CosmosExplorer
# 432       Despair 2022-08-18 22:00:00                      SolitaryDescent
#
#       Platform                             Hashtags  Retweets  Likes  \
# 570    Twitter  #Mesmerizing #NightDancePerformance      40.0   80.0
# 470  Instagram                  #Joy #SimpleMoments      40.0   80.0
# 368  Instagram          #Elation #RareBookDiscovery      40.0   80.0
# 540  Instagram                #Joy #WorldCupTriumph      40.0   80.0
# 560  Instagram           #Tranquility #SunsetBeauty      40.0   80.0
# 355    Twitter       #Anticipation #AdventureAwaits      40.0   80.0
# 402  Instagram         #Wonder #StargazingAdventure      40.0   80.0
# 530    Twitter    #Excitement #MoviePremiereThrills      40.0   80.0
# 382  Instagram         #Wonder #StargazingAdventure      40.0   80.0
# 432  Instagram           #Despair #AbyssOfHeartache      40.0   80.0
#
#           Country  Year  Month  Day  Hour
# 570           USA  2018      6   15    22
# 470           USA  2021      8   20    15
# 368           USA  2018      9   22    16
# 540        Brazil  2018      7   15    21
# 560        Canada  2021      7   10    19
# 355         India  2022      7   25    10
# 402  South Africa  2018      7    8    23
# 530           USA  2018     10   12    20
# 382  South Africa  2018      7    8    23
# 432  South Africa  2022      8   18    22

# %%
# pd.set_option('display.float_format', lambda x: '%.2f' % x)
df_corr = df.corr(numeric_only=True).round(2)
df_corr.style.format("{:.2f}").background_gradient(cmap="coolwarm")
# df.corr(numeric_only=True)
# Out:
# <style type="text/css">
# #T_a1640_row0_col0, #T_a1640_row1_col1, #T_a1640_row1_col2, #T_a1640_row2_col1, #T_a1640_row2_col2, #T_a1640_row3_col3, #T_a1640_row4_col4, #T_a1640_row5_col5, #T_a1640_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1640_row0_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_a1640_row0_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_a1640_row0_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_a1640_row0_col4 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_a1640_row0_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a1640_row0_col6 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a1640_row1_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_a1640_row1_col3, #T_a1640_row2_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_a1640_row1_col4, #T_a1640_row2_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a1640_row1_col5, #T_a1640_row2_col5, #T_a1640_row5_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a1640_row1_col6, #T_a1640_row2_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_a1640_row2_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_a1640_row3_col0, #T_a1640_row6_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a1640_row3_col1, #T_a1640_row3_col2, #T_a1640_row3_col4, #T_a1640_row3_col6, #T_a1640_row4_col3, #T_a1640_row4_col5, #T_a1640_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a1640_row3_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a1640_row4_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_a1640_row4_col1, #T_a1640_row4_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_a1640_row4_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_a1640_row5_col1, #T_a1640_row5_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a1640_row5_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a1640_row5_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_a1640_row6_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_a1640_row6_col1, #T_a1640_row6_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_a1640_row6_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_a1640_row6_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1640">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1640_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_a1640_level0_col1" class="col_heading level0 col1" >Retweets</th>
#       <th id="T_a1640_level0_col2" class="col_heading level0 col2" >Likes</th>
#       <th id="T_a1640_level0_col3" class="col_heading level0 col3" >Year</th>
#       <th id="T_a1640_level0_col4" class="col_heading level0 col4" >Month</th>
#       <th id="T_a1640_level0_col5" class="col_heading level0 col5" >Day</th>
#       <th id="T_a1640_level0_col6" class="col_heading level0 col6" >Hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1640_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_a1640_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a1640_row0_col1" class="data row0 col1" >0.39</td>
#       <td id="T_a1640_row0_col2" class="data row0 col2" >0.38</td>
#       <td id="T_a1640_row0_col3" class="data row0 col3" >0.10</td>
#       <td id="T_a1640_row0_col4" class="data row0 col4" >0.44</td>
#       <td id="T_a1640_row0_col5" class="data row0 col5" >-0.08</td>
#       <td id="T_a1640_row0_col6" class="data row0 col6" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_a1640_level0_row1" class="row_heading level0 row1" >Retweets</th>
#       <td id="T_a1640_row1_col0" class="data row1 col0" >0.39</td>
#       <td id="T_a1640_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_a1640_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_a1640_row1_col3" class="data row1 col3" >-0.04</td>
#       <td id="T_a1640_row1_col4" class="data row1 col4" >0.07</td>
#       <td id="T_a1640_row1_col5" class="data row1 col5" >0.01</td>
#       <td id="T_a1640_row1_col6" class="data row1 col6" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_a1640_level0_row2" class="row_heading level0 row2" >Likes</th>
#       <td id="T_a1640_row2_col0" class="data row2 col0" >0.38</td>
#       <td id="T_a1640_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_a1640_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_a1640_row2_col3" class="data row2 col3" >-0.04</td>
#       <td id="T_a1640_row2_col4" class="data row2 col4" >0.07</td>
#       <td id="T_a1640_row2_col5" class="data row2 col5" >0.01</td>
#       <td id="T_a1640_row2_col6" class="data row2 col6" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_a1640_level0_row3" class="row_heading level0 row3" >Year</th>
#       <td id="T_a1640_row3_col0" class="data row3 col0" >0.10</td>
#       <td id="T_a1640_row3_col1" class="data row3 col1" >-0.04</td>
#       <td id="T_a1640_row3_col2" class="data row3 col2" >-0.04</td>
#       <td id="T_a1640_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_a1640_row3_col4" class="data row3 col4" >-0.31</td>
#       <td id="T_a1640_row3_col5" class="data row3 col5" >0.02</td>
#       <td id="T_a1640_row3_col6" class="data row3 col6" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_a1640_level0_row4" class="row_heading level0 row4" >Month</th>
#       <td id="T_a1640_row4_col0" class="data row4 col0" >0.44</td>
#       <td id="T_a1640_row4_col1" class="data row4 col1" >0.07</td>
#       <td id="T_a1640_row4_col2" class="data row4 col2" >0.07</td>
#       <td id="T_a1640_row4_col3" class="data row4 col3" >-0.31</td>
#       <td id="T_a1640_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_a1640_row4_col5" class="data row4 col5" >-0.14</td>
#       <td id="T_a1640_row4_col6" class="data row4 col6" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_a1640_level0_row5" class="row_heading level0 row5" >Day</th>
#       <td id="T_a1640_row5_col0" class="data row5 col0" >-0.08</td>
#       <td id="T_a1640_row5_col1" class="data row5 col1" >0.01</td>
#       <td id="T_a1640_row5_col2" class="data row5 col2" >0.01</td>
#       <td id="T_a1640_row5_col3" class="data row5 col3" >0.02</td>
#       <td id="T_a1640_row5_col4" class="data row5 col4" >-0.14</td>
#       <td id="T_a1640_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_a1640_row5_col6" class="data row5 col6" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_a1640_level0_row6" class="row_heading level0 row6" >Hour</th>
#       <td id="T_a1640_row6_col0" class="data row6 col0" >0.32</td>
#       <td id="T_a1640_row6_col1" class="data row6 col1" >0.20</td>
#       <td id="T_a1640_row6_col2" class="data row6 col2" >0.20</td>
#       <td id="T_a1640_row6_col3" class="data row6 col3" >-0.09</td>
#       <td id="T_a1640_row6_col4" class="data row6 col4" >0.14</td>
#       <td id="T_a1640_row6_col5" class="data row6 col5" >0.04</td>
#       <td id="T_a1640_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unnamed data should be removed
# Total correlation between likes and retweets

# %%
df_corr = df.corr(numeric_only=True).round(2)
df_corr.style.format("{:.2f}").background_gradient(cmap="magma")
# Out:
# <style type="text/css">
# #T_b0b1d_row0_col0, #T_b0b1d_row1_col1, #T_b0b1d_row1_col2, #T_b0b1d_row2_col1, #T_b0b1d_row2_col2, #T_b0b1d_row3_col3, #T_b0b1d_row4_col4, #T_b0b1d_row5_col5, #T_b0b1d_row6_col6 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_b0b1d_row0_col1 {
#   background-color: #912b81;
#   color: #f1f1f1;
# }
# #T_b0b1d_row0_col2 {
#   background-color: #8e2a81;
#   color: #f1f1f1;
# }
# #T_b0b1d_row0_col3 {
#   background-color: #6a1c81;
#   color: #f1f1f1;
# }
# #T_b0b1d_row0_col4 {
#   background-color: #d3436e;
#   color: #f1f1f1;
# }
# #T_b0b1d_row0_col5 {
#   background-color: #07061c;
#   color: #f1f1f1;
# }
# #T_b0b1d_row0_col6 {
#   background-color: #832681;
#   color: #f1f1f1;
# }
# #T_b0b1d_row1_col0 {
#   background-color: #9b2e7f;
#   color: #f1f1f1;
# }
# #T_b0b1d_row1_col3, #T_b0b1d_row2_col3 {
#   background-color: #3d0f71;
#   color: #f1f1f1;
# }
# #T_b0b1d_row1_col4, #T_b0b1d_row2_col4 {
#   background-color: #601880;
#   color: #f1f1f1;
# }
# #T_b0b1d_row1_col5, #T_b0b1d_row2_col5, #T_b0b1d_row5_col4 {
#   background-color: #1e1149;
#   color: #f1f1f1;
# }
# #T_b0b1d_row1_col6, #T_b0b1d_row2_col6 {
#   background-color: #57157e;
#   color: #f1f1f1;
# }
# #T_b0b1d_row2_col0 {
#   background-color: #982d80;
#   color: #f1f1f1;
# }
# #T_b0b1d_row3_col0, #T_b0b1d_row6_col3 {
#   background-color: #2c115f;
#   color: #f1f1f1;
# }
# #T_b0b1d_row3_col1, #T_b0b1d_row3_col2, #T_b0b1d_row3_col4, #T_b0b1d_row3_col6, #T_b0b1d_row4_col3, #T_b0b1d_row4_col5, #T_b0b1d_row5_col0 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_b0b1d_row3_col5 {
#   background-color: #21114e;
#   color: #f1f1f1;
# }
# #T_b0b1d_row4_col0 {
#   background-color: #ae347b;
#   color: #f1f1f1;
# }
# #T_b0b1d_row4_col1, #T_b0b1d_row4_col2 {
#   background-color: #160f3b;
#   color: #f1f1f1;
# }
# #T_b0b1d_row4_col6 {
#   background-color: #400f74;
#   color: #f1f1f1;
# }
# #T_b0b1d_row5_col1, #T_b0b1d_row5_col2 {
#   background-color: #06051a;
#   color: #f1f1f1;
# }
# #T_b0b1d_row5_col3 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_b0b1d_row5_col6 {
#   background-color: #1a1042;
#   color: #f1f1f1;
# }
# #T_b0b1d_row6_col0 {
#   background-color: #802582;
#   color: #f1f1f1;
# }
# #T_b0b1d_row6_col1, #T_b0b1d_row6_col2 {
#   background-color: #491078;
#   color: #f1f1f1;
# }
# #T_b0b1d_row6_col4 {
#   background-color: #752181;
#   color: #f1f1f1;
# }
# #T_b0b1d_row6_col5 {
#   background-color: #29115a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0b1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0b1d_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_b0b1d_level0_col1" class="col_heading level0 col1" >Retweets</th>
#       <th id="T_b0b1d_level0_col2" class="col_heading level0 col2" >Likes</th>
#       <th id="T_b0b1d_level0_col3" class="col_heading level0 col3" >Year</th>
#       <th id="T_b0b1d_level0_col4" class="col_heading level0 col4" >Month</th>
#       <th id="T_b0b1d_level0_col5" class="col_heading level0 col5" >Day</th>
#       <th id="T_b0b1d_level0_col6" class="col_heading level0 col6" >Hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0b1d_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_b0b1d_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_b0b1d_row0_col1" class="data row0 col1" >0.39</td>
#       <td id="T_b0b1d_row0_col2" class="data row0 col2" >0.38</td>
#       <td id="T_b0b1d_row0_col3" class="data row0 col3" >0.10</td>
#       <td id="T_b0b1d_row0_col4" class="data row0 col4" >0.44</td>
#       <td id="T_b0b1d_row0_col5" class="data row0 col5" >-0.08</td>
#       <td id="T_b0b1d_row0_col6" class="data row0 col6" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_b0b1d_level0_row1" class="row_heading level0 row1" >Retweets</th>
#       <td id="T_b0b1d_row1_col0" class="data row1 col0" >0.39</td>
#       <td id="T_b0b1d_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_b0b1d_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_b0b1d_row1_col3" class="data row1 col3" >-0.04</td>
#       <td id="T_b0b1d_row1_col4" class="data row1 col4" >0.07</td>
#       <td id="T_b0b1d_row1_col5" class="data row1 col5" >0.01</td>
#       <td id="T_b0b1d_row1_col6" class="data row1 col6" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b0b1d_level0_row2" class="row_heading level0 row2" >Likes</th>
#       <td id="T_b0b1d_row2_col0" class="data row2 col0" >0.38</td>
#       <td id="T_b0b1d_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_b0b1d_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_b0b1d_row2_col3" class="data row2 col3" >-0.04</td>
#       <td id="T_b0b1d_row2_col4" class="data row2 col4" >0.07</td>
#       <td id="T_b0b1d_row2_col5" class="data row2 col5" >0.01</td>
#       <td id="T_b0b1d_row2_col6" class="data row2 col6" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_b0b1d_level0_row3" class="row_heading level0 row3" >Year</th>
#       <td id="T_b0b1d_row3_col0" class="data row3 col0" >0.10</td>
#       <td id="T_b0b1d_row3_col1" class="data row3 col1" >-0.04</td>
#       <td id="T_b0b1d_row3_col2" class="data row3 col2" >-0.04</td>
#       <td id="T_b0b1d_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_b0b1d_row3_col4" class="data row3 col4" >-0.31</td>
#       <td id="T_b0b1d_row3_col5" class="data row3 col5" >0.02</td>
#       <td id="T_b0b1d_row3_col6" class="data row3 col6" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_b0b1d_level0_row4" class="row_heading level0 row4" >Month</th>
#       <td id="T_b0b1d_row4_col0" class="data row4 col0" >0.44</td>
#       <td id="T_b0b1d_row4_col1" class="data row4 col1" >0.07</td>
#       <td id="T_b0b1d_row4_col2" class="data row4 col2" >0.07</td>
#       <td id="T_b0b1d_row4_col3" class="data row4 col3" >-0.31</td>
#       <td id="T_b0b1d_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_b0b1d_row4_col5" class="data row4 col5" >-0.14</td>
#       <td id="T_b0b1d_row4_col6" class="data row4 col6" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_b0b1d_level0_row5" class="row_heading level0 row5" >Day</th>
#       <td id="T_b0b1d_row5_col0" class="data row5 col0" >-0.08</td>
#       <td id="T_b0b1d_row5_col1" class="data row5 col1" >0.01</td>
#       <td id="T_b0b1d_row5_col2" class="data row5 col2" >0.01</td>
#       <td id="T_b0b1d_row5_col3" class="data row5 col3" >0.02</td>
#       <td id="T_b0b1d_row5_col4" class="data row5 col4" >-0.14</td>
#       <td id="T_b0b1d_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_b0b1d_row5_col6" class="data row5 col6" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_b0b1d_level0_row6" class="row_heading level0 row6" >Hour</th>
#       <td id="T_b0b1d_row6_col0" class="data row6 col0" >0.32</td>
#       <td id="T_b0b1d_row6_col1" class="data row6 col1" >0.20</td>
#       <td id="T_b0b1d_row6_col2" class="data row6 col2" >0.20</td>
#       <td id="T_b0b1d_row6_col3" class="data row6 col3" >-0.09</td>
#       <td id="T_b0b1d_row6_col4" class="data row6 col4" >0.14</td>
#       <td id="T_b0b1d_row6_col5" class="data row6 col5" >0.04</td>
#       <td id="T_b0b1d_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# When applying a background gradient, especially in data visualization libraries like Pandas or Matplotlib, the cmap argument (colormap) specifies the color scheme to be used. While coolwarm provides a diverging colormap ranging from cool blues to warm reds, many other options exist, each with a distinct aesthetic and purpose.
# Here are some categories of colormaps and examples of other colors you could use:
# 1. Sequential Colormaps: These colormaps are designed to show a progression of values, typically from low to high, using a single hue or a gradual change in lightness/saturation.
# Examples: viridis, plasma, inferno, magma, gray, Blues, Greens, Reds, Purples, Oranges.
# 2. Diverging Colormaps: Similar to coolwarm, these colormaps emphasize a central neutral value and diverge to two distinct colors at the extremes, suitable for showing deviations from a mean or a zero point.
# Examples: seismic, RdBu, PiYG, PRGn, BrBG, bwr.
# 3. Qualitative Colormaps: These colormaps are designed to distinguish between discrete categories or groups, using distinct and easily differentiable colors.
# Examples: tab10, tab20, Paired, Set1, Set2, Dark2.
# 4. Cyclic Colormaps: These colormaps are useful for data that wraps around a central point, like angles or phases, where the start and end colors are the same or very similar.
# Examples: twilight, hsv.
# To choose the best colormap, consider:
# Data Type: Is your data sequential, diverging, or categorical?
# Clarity: Does the colormap effectively convey the information without causing misinterpretations?
# Accessibility: Is the colormap colorblind-friendly? (e.g., viridis is often recommended for this).
# Aesthetics: Does the colormap align with the overall design and purpose of your visualization?

# %%
df['text_len'] = df['Text'].str.len()
df['word_count'] = df['Text'].str.split().str.len()
df['hashtag_count'] = df['Hashtags'].str.count('#')
df['emoji_count'] = df['Text'].str.count(r'[^\w\s,]')  # emojis/símbolos

df[['text_len', 'word_count', 'hashtag_count', 'emoji_count', 'Likes', 'Retweets']].corr()
# Out:
#                text_len  word_count  hashtag_count  emoji_count     Likes  \
# text_len       1.000000    0.948347            NaN     0.356918  0.200187
# word_count     0.948347    1.000000            NaN     0.261845  0.196229
# hashtag_count       NaN         NaN            NaN          NaN       NaN
# emoji_count    0.356918    0.261845            NaN     1.000000  0.174394
# Likes          0.200187    0.196229            NaN     0.174394  1.000000
# Retweets       0.202392    0.197125            NaN     0.181458  0.998482
#
#                Retweets
# text_len       0.202392
# word_count     0.197125
# hashtag_count       NaN
# emoji_count    0.181458
# Likes          0.998482
# Retweets       1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True)

plt.rcParams['figure.figsize'] = (20,7)

plt.show()

# %%
df_groupby = df.groupby('Platform')[['Likes', 'Retweets']].mean().sort_values(by='Likes', ascending=False)
df_groupby.style.format("{:.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c12b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c12b_level0_col0" class="col_heading level0 col0" >Likes</th>
#       <th id="T_6c12b_level0_col1" class="col_heading level0 col1" >Retweets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Platform</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c12b_level0_row0" class="row_heading level0 row0" >Instagram</th>
#       <td id="T_6c12b_row0_col0" class="data row0 col0" >45.1</td>
#       <td id="T_6c12b_row0_col1" class="data row0 col1" >22.6</td>
#     </tr>
#     <tr>
#       <th id="T_6c12b_level0_row1" class="row_heading level0 row1" >Facebook</th>
#       <td id="T_6c12b_row1_col0" class="data row1 col0" >41.9</td>
#       <td id="T_6c12b_row1_col1" class="data row1 col1" >21.0</td>
#     </tr>
#     <tr>
#       <th id="T_6c12b_level0_row2" class="row_heading level0 row2" >Twitter</th>
#       <td id="T_6c12b_row2_col0" class="data row2 col0" >41.6</td>
#       <td id="T_6c12b_row2_col1" class="data row2 col1" >20.9</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['Country'].value_counts()
# Out:
# Country
# USA               188
# UK                143
# Canada            135
# Australia          75
# India              70
# Brazil             17
# France             16
# Japan              15
# Germany            14
# Italy              11
# Spain               6
# South Africa        6
# Greece              5
# Netherlands         4
# Switzerland         3
# Portugal            2
# Austria             2
# Belgium             2
# Denmark             2
# Czech Republic      2
# Sweden              2
# Colombia            1
# Scotland            1
# Kenya               1
# Jamaica             1
# Ireland             1
# China               1
# Norway              1
# Cambodia            1
# Maldives            1
# Peru                1
# Jordan              1
# Thailand            1
# Name: count, dtype: int64

# %% [markdown]
# Strings might have empty values and that messes up de 'country' data

# %%
df['Country'].value_counts(normalize=True) * 100
# Out:
# Country
# USA               25.683060
# UK                19.535519
# Canada            18.442623
# Australia         10.245902
# India              9.562842
# Brazil             2.322404
# France             2.185792
# Japan              2.049180
# Germany            1.912568
# Italy              1.502732
# Spain              0.819672
# South Africa       0.819672
# Greece             0.683060
# Netherlands        0.546448
# Switzerland        0.409836
# Portugal           0.273224
# Austria            0.273224
# Belgium            0.273224
# Denmark            0.273224
# Czech Republic     0.273224
# Sweden             0.273224
# Colombia           0.136612
# Scotland           0.136612
# Kenya              0.136612
# Jamaica            0.136612
# Ireland            0.136612
# China              0.136612
# Norway             0.136612
# Cambodia           0.136612
# Maldives           0.136612
# Peru               0.136612
# Jordan             0.136612
# Thailand           0.136612
# Name: proportion, dtype: float64

# %%
df.groupby('Country')[['Likes', 'Retweets', 'emoji_count', 'word_count']].mean().sort_values(by='Likes', ascending=False)
# Out:
#                     Likes   Retweets  emoji_count  word_count
# Country
# South Africa    71.666667  35.833333     1.166667   12.833333
# Belgium         70.000000  35.000000     1.000000   10.500000
# Thailand        70.000000  35.000000     1.000000   21.000000
# Sweden          70.000000  35.000000     1.000000   10.000000
# Jamaica         60.000000  30.000000     3.000000   17.000000
# Jordan          60.000000  30.000000     1.000000   15.000000
# Portugal        55.000000  28.000000     1.000000   11.000000
# Switzerland     55.000000  27.333333     1.333333   14.666667
# Colombia        55.000000  28.000000     5.000000   15.000000
# Peru            55.000000  28.000000     1.000000   16.000000
# Netherlands     53.750000  26.750000     1.250000   13.250000
# Brazil          52.941176  26.352941     1.176471   15.235294
# Japan           52.333333  26.200000     1.333333   14.800000
# Ireland         50.000000  25.000000     3.000000   18.000000
# Germany         48.214286  24.214286     1.285714   14.428571
# Italy           46.818182  23.545455     1.181818   14.909091
# France          46.250000  23.250000     1.125000   15.437500
# Norway          45.000000  22.000000     2.000000   14.000000
# Scotland        45.000000  22.000000     2.000000   22.000000
# Austria         45.000000  22.000000     1.000000   10.000000
# Kenya           45.000000  22.000000     2.000000   19.000000
# Maldives        45.000000  22.000000     1.000000   15.000000
# USA             44.457447  22.308511     1.898936   13.053191
# Greece          44.000000  22.200000     1.000000   13.400000
# Spain           41.666667  21.000000     1.166667   14.166667
# UK              40.748252  20.496503     1.895105   13.272727
# Canada          40.651852  20.377778     1.888889   13.007407
# Denmark         40.000000  20.000000     1.000000   10.500000
# Cambodia        40.000000  20.000000     1.000000   14.000000
# Australia       39.013333  19.520000     1.266667   13.013333
# India           38.214286  19.057143     1.114286   11.985714
# Czech Republic  35.000000  18.000000     3.000000   10.000000
# China           35.000000  18.000000     1.000000   14.000000

# %%
df_groupby = df.groupby('Sentiment')[['Likes', 'Retweets']].mean().sort_values(by='Retweets', ascending=False)
df_groupby.style.format("{:.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_15f04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15f04_level0_col0" class="col_heading level0 col0" >Likes</th>
#       <th id="T_15f04_level0_col1" class="col_heading level0 col1" >Retweets</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sentiment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15f04_level0_row0" class="row_heading level0 row0" >Mesmerizing</th>
#       <td id="T_15f04_row0_col0" class="data row0 col0" >80.0</td>
#       <td id="T_15f04_row0_col1" class="data row0 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row1" class="row_heading level0 row1" >Motivation</th>
#       <td id="T_15f04_row1_col0" class="data row1 col0" >80.0</td>
#       <td id="T_15f04_row1_col1" class="data row1 col1" >40.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row2" class="row_heading level0 row2" >Wonder</th>
#       <td id="T_15f04_row2_col0" class="data row2 col0" >73.3</td>
#       <td id="T_15f04_row2_col1" class="data row2 col1" >36.7</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row3" class="row_heading level0 row3" >Whispers of the Past</th>
#       <td id="T_15f04_row3_col0" class="data row3 col0" >70.0</td>
#       <td id="T_15f04_row3_col1" class="data row3 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row4" class="row_heading level0 row4" >Suspense</th>
#       <td id="T_15f04_row4_col0" class="data row4 col0" >70.0</td>
#       <td id="T_15f04_row4_col1" class="data row4 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row5" class="row_heading level0 row5" >Imagination</th>
#       <td id="T_15f04_row5_col0" class="data row5 col0" >70.0</td>
#       <td id="T_15f04_row5_col1" class="data row5 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row6" class="row_heading level0 row6" >Challenge</th>
#       <td id="T_15f04_row6_col0" class="data row6 col0" >70.0</td>
#       <td id="T_15f04_row6_col1" class="data row6 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row7" class="row_heading level0 row7" >InnerJourney</th>
#       <td id="T_15f04_row7_col0" class="data row7 col0" >70.0</td>
#       <td id="T_15f04_row7_col1" class="data row7 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row8" class="row_heading level0 row8" >Resilience</th>
#       <td id="T_15f04_row8_col0" class="data row8 col0" >70.0</td>
#       <td id="T_15f04_row8_col1" class="data row8 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row9" class="row_heading level0 row9" >Exhaustion</th>
#       <td id="T_15f04_row9_col0" class="data row9 col0" >70.0</td>
#       <td id="T_15f04_row9_col1" class="data row9 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row10" class="row_heading level0 row10" >Emotion</th>
#       <td id="T_15f04_row10_col0" class="data row10 col0" >70.0</td>
#       <td id="T_15f04_row10_col1" class="data row10 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row11" class="row_heading level0 row11" >Ecstasy</th>
#       <td id="T_15f04_row11_col0" class="data row11 col0" >70.0</td>
#       <td id="T_15f04_row11_col1" class="data row11 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row12" class="row_heading level0 row12" >Mindfulness</th>
#       <td id="T_15f04_row12_col0" class="data row12 col0" >70.0</td>
#       <td id="T_15f04_row12_col1" class="data row12 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row13" class="row_heading level0 row13" >CulinaryOdyssey</th>
#       <td id="T_15f04_row13_col0" class="data row13 col0" >70.0</td>
#       <td id="T_15f04_row13_col1" class="data row13 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row14" class="row_heading level0 row14" >Wonderment</th>
#       <td id="T_15f04_row14_col0" class="data row14 col0" >70.0</td>
#       <td id="T_15f04_row14_col1" class="data row14 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row15" class="row_heading level0 row15" >Culinary Adventure</th>
#       <td id="T_15f04_row15_col0" class="data row15 col0" >70.0</td>
#       <td id="T_15f04_row15_col1" class="data row15 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row16" class="row_heading level0 row16" >Energy</th>
#       <td id="T_15f04_row16_col0" class="data row16 col0" >70.0</td>
#       <td id="T_15f04_row16_col1" class="data row16 col1" >35.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row17" class="row_heading level0 row17" >Isolation</th>
#       <td id="T_15f04_row17_col0" class="data row17 col0" >65.0</td>
#       <td id="T_15f04_row17_col1" class="data row17 col1" >32.5</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row18" class="row_heading level0 row18" >Tranquility</th>
#       <td id="T_15f04_row18_col0" class="data row18 col0" >65.0</td>
#       <td id="T_15f04_row18_col1" class="data row18 col1" >32.5</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row19" class="row_heading level0 row19" >Thrill</th>
#       <td id="T_15f04_row19_col0" class="data row19 col0" >62.5</td>
#       <td id="T_15f04_row19_col1" class="data row19 col1" >31.2</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row20" class="row_heading level0 row20" >Adventure</th>
#       <td id="T_15f04_row20_col0" class="data row20 col0" >61.7</td>
#       <td id="T_15f04_row20_col1" class="data row20 col1" >30.7</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row21" class="row_heading level0 row21" >Friendship</th>
#       <td id="T_15f04_row21_col0" class="data row21 col0" >60.0</td>
#       <td id="T_15f04_row21_col1" class="data row21 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row22" class="row_heading level0 row22" >Heartache</th>
#       <td id="T_15f04_row22_col0" class="data row22 col0" >60.0</td>
#       <td id="T_15f04_row22_col1" class="data row22 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row23" class="row_heading level0 row23" >Freedom</th>
#       <td id="T_15f04_row23_col0" class="data row23 col0" >60.0</td>
#       <td id="T_15f04_row23_col1" class="data row23 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row24" class="row_heading level0 row24" >EmotionalStorm</th>
#       <td id="T_15f04_row24_col0" class="data row24 col0" >60.0</td>
#       <td id="T_15f04_row24_col1" class="data row24 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row25" class="row_heading level0 row25" >Engagement</th>
#       <td id="T_15f04_row25_col0" class="data row25 col0" >60.0</td>
#       <td id="T_15f04_row25_col1" class="data row25 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row26" class="row_heading level0 row26" >Spark</th>
#       <td id="T_15f04_row26_col0" class="data row26 col0" >60.0</td>
#       <td id="T_15f04_row26_col1" class="data row26 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row27" class="row_heading level0 row27" >Coziness</th>
#       <td id="T_15f04_row27_col0" class="data row27 col0" >60.0</td>
#       <td id="T_15f04_row27_col1" class="data row27 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row28" class="row_heading level0 row28" >Disappointment</th>
#       <td id="T_15f04_row28_col0" class="data row28 col0" >60.0</td>
#       <td id="T_15f04_row28_col1" class="data row28 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row29" class="row_heading level0 row29" >Solitude</th>
#       <td id="T_15f04_row29_col0" class="data row29 col0" >60.0</td>
#       <td id="T_15f04_row29_col1" class="data row29 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row30" class="row_heading level0 row30" >Solace</th>
#       <td id="T_15f04_row30_col0" class="data row30 col0" >60.0</td>
#       <td id="T_15f04_row30_col1" class="data row30 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_15f04_level0_row31" class="row_heading le

# %%
df.drop(columns='Unnamed: 0.1', inplace=True)
df.rename(columns={'Unnamed: 0':'Id'}, inplace=True)
df.isnull().sum()
df.dtypes

df["Platform"] = df["Platform"].astype(str).str.strip().str.title()
top10_sentiments = df["Sentiment"].value_counts().head(10).index
df_platform = df[df["Sentiment"].isin(top10_sentiments)].copy()

print("Platforms in dataset:", df_platform["Platform"].unique())
# Out:
# Platforms in dataset: ['Twitter' 'Instagram' 'Facebook']

# %%
import matplotlib.pyplot as plt

# Plot pie chart
df['Platform'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    ylabel=''  # Removes the default "count" label
)

# Title
plt.title('Percentages of Platforms')

# Move legend to avoid overlap (you can try 'upper left', 'lower right', etc.)
plt.legend(loc='upper left')

# Adjust layout to avoid elements being cut off
plt.tight_layout()

# Show the chart
plt.show()
